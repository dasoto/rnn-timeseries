# %%
from process_data import clean_data, create_index, pivot_data, clean_data2
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, LSTM, Dropout, Activation, TimeDistributed
from keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
from keras.models import load_model
import matplotlib.pyplot as plt
import time
import datetime
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

# %%
def data_mimo(X,y,lookback=1):
    newX = []
    newY = []
    for i in range(len(y)-lookback):
        newX.append(X[i:i+1+lookback,:])
        newY.append(y[i:i+1+lookback])
    return np.array(newX), np.array(newY)



def mlp(lookback,num_features):
    model = Sequential()
    model.add(TimeDistributed(Dense(2*lookback+1,activation='tanh'), input_shape=(lookback+1,num_features)))
    model.add(Dropout(0.2))
    model.add(TimeDistributed(Dense(lookback+1,activation='tanh')))
    model.add(Dropout(0.2))
    model.add(TimeDistributed(Dense(1,activation='linear')))
    model.compile(loss='mean_squared_error', optimizer='adam')
    model.summary()
    return model


def train_rnn(df,date_predict,lookback,epochs=100):
    #Preparting data to Train
    print('Preparing data to Train')
    date_p = datetime.datetime.strptime(date_predict, "%Y-%m-%d").date()
    date_limit = (date_p - datetime.timedelta(days=1)).strftime('%Y-%m-%d')
    date_start = (date_p - datetime.timedelta(days=90+lookback//24)).strftime('%Y-%m-%d')
    sk = df[:date_limit].copy()
    print(sk.shape)
    sk = sk.drop(['TRADEDATE', 'RTENERGY'], axis=1)

    #sk.hourofday = sk.hourofday.dt.seconds/3600
    sk = sk[date_start:]
    #sk = sk[24:]
    print('Shape os SK:',sk.shape)
    y = sk.pop('DAENERGY').values
    X = sk.values[:,1:]
    X, y = data_mimo(X,y,lookback)
    y = y.reshape(len(y),y.shape[1],1)
    print('Shape of X',X.shape)
    #X = X[1:]
    #y = y[1:]
    print('Shape of X',X.shape)
    print('YYYY')
    print(y.shape)
    
    model = mlp(lookback,X.shape[2])
    #model = create_rnn(lookback,X.shape[2])

    #X = X.reshape(X.shape[0],X.shape[1],1)
    filepath="weights-improvement-{epoch:02d}-{val_loss:.2f}.hdf5"
    filepath="best_model_mlp-mimo-2.hdf5"

    checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
    early_stop = EarlyStopping(monitor='val_loss', patience=30, verbose=1)
    tensorboard = TensorBoard(log_dir='./logs/mlp'+str(time.time()), 
                              histogram_freq=0, 
                              batch_size=24, 
                              write_graph=True, 
                              write_grads=False, 
                              write_images=True, 
                              )
    # #Training Model
    model.fit(
        X,
        y,
        batch_size=24,  #168, 
        epochs=epochs,
        shuffle = False,
        validation_split=0.1, callbacks=[tensorboard, checkpoint, early_stop])  #0.0857 #0.05 #0.1

    #preparing data to Predict
    return model, X, y

def predict_day(date_predict,model,lookback=168):
    date_p = datetime.datetime.strptime(date_predict, "%Y-%m-%d").date()
    date_limit = (date_p - datetime.timedelta(days=1)).strftime('%Y-%m-%d')
    date_start = (date_p - datetime.timedelta(days=42)).strftime('%Y-%m-%d')

    df_predict = df.copy()
    df_predict = df_predict[:date_predict]

    df_predict = df_predict.drop(['TRADEDATE', 'RTENERGY'], axis=1)

    #df_predict.hourofday = df_predict.hourofday.dt.seconds/3600
    df_predict = df_predict[date_start:]
    y = df_predict.pop('DAENERGY').values
    X = df_predict.values[:,1:]
    #X,y = data_lstm(X,y,lookback)
    X,y = data_mimo(X,y,lookback)
    input_p = X[-24:]   #-24
    input_p = X[-1:]
    pred = model.predict(input_p,batch_size=1)

    results = df[date_predict].copy()
    # pred_ada = model.predict(input_p.values)
    results['forecast'] = pred[0]
    RMSE = get_rmse(results['DAENERGY'].values, pred)
    return results, RMSE

def plot_results(results,date_predict):
    RMSE = get_rmse(results['DAENERGY'], results['forecast'])
    fig, ax = plt.subplots(figsize=(9,4))
    # npre = 24
    ax.set(title='DAENERGY '+ 'RMSE: {:.3f} for {}'.format(RMSE, date_predict), xlabel='Date', ylabel='Price DAENERGY')
    #
    # # Plot data points
    results['DAENERGY'].plot(ax=ax, style='o', label='Observed')
    #
    # # Plot predictions
    results.forecast.plot(ax=ax, style='r--', label='forecast')
    # #ci = predict_ci.loc[date_predict]
    # #ax.fill_between(ci.index, ci.iloc[:,0], ci.iloc[:,1], color='r', alpha=0.1)
    legend = ax.legend(loc='lower right')


def get_rmse(pred,real):
    return np.sqrt(((pred-real)**2).sum()/pred.shape[0])

def create_date_range(start_date, end_date):
    start_dt = datetime.datetime.strptime(start_date, "%Y-%m-%d").date()
    end_dt = datetime.datetime.strptime(end_date, "%Y-%m-%d").date()
    dates = []
    cur_dt = start_dt
    dates.append(start_date)
    while cur_dt<end_dt:
        cur_dt = cur_dt + datetime.timedelta(days=1)
        dates.append(cur_dt.strftime('%Y-%m-%d'))
    return dates


def create_features(df):
    df = df.copy()
    features = ['Ph-1', 'Ph-2', 'Ph-3', 'Ph-24', 'Ph-25', 'Ph-48', 'Ph-49',
                'Ph-72','Ph-73', 'Ph-96', 'Ph-97', 'Ph-120', 'Ph-121', 'Ph-144',
                'Ph-145', 'Ph-168']
    deltas = [1, 2, 3, 24, 25, 48, 49, 72, 73, 96, 97, 120, 121, 144, 145, 168]

    for col, shift in zip(features, deltas):
        df[col] = df.DAENERGY.shift(shift)
    return df

def create_rollings(df):
    df = df.copy()
    means_cols = ['mean_3','mean_6','mean_9','mean_12','mean_24']
    means_values = [3,6,9,12,24]
    
    for col, val in zip(means_cols, means_values):
        df[col] = pd.Series.rolling(df.DAENERGY, window=val, center = False).mean()
        df[col] = df[col].shift(24)
    
    #df['p_1'] = df.DAENERGY.shift(1)
    df['p_24'] = df.DAENERGY.shift(24)
    df['p_48'] = df.DAENERGY.shift(48)
    return df        

def MAPE(y_true, y_pred):
    return 1.0/len(y_true)*(np.abs((y_true-y_pred))/y_true*100).sum()

from keras.optimizers import RMSprop, Adam, Adadelta

# %%
df = pivot_data('../data/Data.txt')
#scaler = MinMaxScaler(feature_range=(-1,1)).fit(df.DAENERGY)
#df.DAENERGY = scaler.transform(df.DAENERGY)
df = clean_data(df)
df = create_index(df)
df2 = pivot_data('../data/FurtherBack.txt','2017-05-15','2017-07-07')
df2 = clean_data2(df2)
df2 = create_index(df2)
df = pd.concat([df2,df])


df = create_rollings(df)
df = df.dropna()

wdf = pd.read_csv('../data/wstation.csv', delim_whitespace=True)
temp_cols = []
cols = df.columns.values
for col in cols:
    if len(col)==4 and col not in ['LOAD', 'p_48', 'p_72']:
        temp_cols.append(col)
        
wdf = wdf.drop_duplicates(subset = ['CALL'])

temps = pd.DataFrame(temp_cols)
temps.columns = ['CALL']
result = pd.merge(temps, wdf, how='left', on=['CALL'])
result = result[['CALL','LAT','LON']]
result = result.dropna()

from sklearn.cluster import KMeans
clusters = KMeans(n_clusters = 4).fit(result[['LAT','LON']])

result['Cluster'] = clusters.labels_

df['Temp_C_0']=df[result[result.Cluster==0]['CALL']].mean(axis=1)
df['Temp_C_1']=df[result[result.Cluster==1]['CALL']].mean(axis=1)
df['Temp_C_2']=df[result[result.Cluster==2]['CALL']].mean(axis=1)
df['Temp_C_3']=df[result[result.Cluster==3]['CALL']].mean(axis=1)

df = df.drop(temp_cols, axis=1)


list_scalers = dict()
for c in df.columns.values:
    list_scalers[c] = MinMaxScaler()
    list_scalers[c].fit(df[c].values.reshape(-1,1))
    df[c] = list_scalers[c].transform(df[c].values.reshape(-1,1))


print('Training the model...')

lookback=23#72#48#168
# Out:
# Training the model...

# %%
lookback=23

# %%
#df.DAENERGY = list_scalers['DAENERGY'].inverse_transform(df.DAENERGY.values)
start = time.time()
model, X, y = train_rnn(df,'2017-10-01',lookback=23,epochs=500)
print('Training time : {}'.format(time.time() - start))
# Out:
# Preparing data to Train
# (3335, 18)
# ('Shape os SK:', (2208, 16))
# ('Shape of X', (2185, 24, 14))
# ('Shape of X', (2185, 24, 14))
# YYYY
# (2185, 24, 1)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed_31 (TimeDis (None, 24, 47)            705
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 24, 47)            0
# _________________________________________________________________
# time_distributed_32 (TimeDis (None, 24, 24)            1152
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 24, 24)            0
# _________________________________________________________________
# time_distributed_33 (TimeDis (None, 24, 1)             25
# =================================================================
# Total params: 1,882
# Trainable params: 1,882
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1966 samples, validate on 219 samples
# Epoch 1/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0416Epoch 00000: val_loss improved from inf to 0.03045, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0291 - val_loss: 0.0304
# Epoch 2/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0110Epoch 00001: val_loss improved from 0.03045 to 0.02242, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0091 - val_loss: 0.0224
# Epoch 3/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0068Epoch 00002: val_loss improved from 0.02242 to 0.01829, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0058 - val_loss: 0.0183
# Epoch 4/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0052Epoch 00003: val_loss improved from 0.01829 to 0.01648, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0044 - val_loss: 0.0165
# Epoch 5/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0042Epoch 00004: val_loss improved from 0.01648 to 0.01640, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0036 - val_loss: 0.0164
# Epoch 6/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0037Epoch 00005: val_loss improved from 0.01640 to 0.01538, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0031 - val_loss: 0.0154
# Epoch 7/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0033Epoch 00006: val_loss improved from 0.01538 to 0.01529, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0028 - val_loss: 0.0153
# Epoch 8/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0032Epoch 00007: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0027 - val_loss: 0.0153
# Epoch 9/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0030Epoch 00008: val_loss improved from 0.01529 to 0.01526, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0025 - val_loss: 0.0153
# Epoch 10/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0030Epoch 00009: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0025 - val_loss: 0.0157
# Epoch 11/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0029Epoch 00010: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0024 - val_loss: 0.0156
# Epoch 12/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0029Epoch 00011: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0024 - val_loss: 0.0155
# Epoch 13/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0028Epoch 00012: val_loss improved from 0.01526 to 0.01525, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0023 - val_loss: 0.0153
# Epoch 14/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0027Epoch 00013: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0023 - val_loss: 0.0154
# Epoch 15/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0027Epoch 00014: val_loss improved from 0.01525 to 0.01497, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0022 - val_loss: 0.0150
# Epoch 16/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0026Epoch 00015: val_loss improved from 0.01497 to 0.01479, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0021 - val_loss: 0.0148
# Epoch 17/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0025Epoch 00016: val_loss improved from 0.01479 to 0.01443, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0021 - val_loss: 0.0144
# Epoch 18/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0024Epoch 00017: val_loss improved from 0.01443 to 0.01408, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0020 - val_loss: 0.0141
# Epoch 19/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0023Epoch 00018: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0019 - val_loss: 0.0141
# Epoch 20/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0022Epoch 00019: val_loss improved from 0.01408 to 0.01389, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0019 - val_loss: 0.0139
# Epoch 21/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0021Epoch 00020: val_loss improved from 0.01389 to 0.01384, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0018 - val_loss: 0.0138
# Epoch 22/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0021Epoch 00021: val_loss improved from 0.01384 to 0.01368, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0017 - val_loss: 0.0137
# Epoch 23/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0021Epoch 00022: val_loss improved from 0.01368 to 0.01352, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0017 - val_loss: 0.0135
# Epoch 24/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0020Epoch 00023: val_loss improved from 0.01352 to 0.01340, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0017 - val_loss: 0.0134
# Epoch 25/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0019Epoch 00024: val_loss improved from 0.01340 to 0.01323, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0016 - val_loss: 0.0132
# Epoch 26/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0019Epoch 00025: val_loss improved from 0.01323 to 0.01309, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0016 - val_loss: 0.0131
# Epoch 27/500
# 1008/1966 [==============>...............] - ETA: 0s - loss: 0.0019Epoch 00026: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0016 - val_loss: 0.0131
# Epoch 28/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0018Epoch 00027: val_loss improved from 0.01309 to 0.01296, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0130
# Epoch 29/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0018    Epoch 00028: val_loss improved from 0.01296 to 0.01282, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0128
# Epoch 30/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0018    Epoch 00029: val_loss improved from 0.01282 to 0.01276, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0128
# Epoch 31/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0017    Epoch 00030: val_loss improved from 0.01276 to 0.01276, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0128
# Epoch 32/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0017    Epoch 00031: val_loss improved from 0.01276 to 0.01260, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0014 - val_loss: 0.0126
# Epoch 33/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0017    Epoch 00032: val_loss improved from 0.01260 to 0.01253, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0014 - val_loss: 0.0125
# Epoch 34/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0017    Epoch 00033: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0014 - val_loss: 0.0126
# Epoch 35/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0017    Epoch 00034: val_loss improved from 0.01253 to 0.01228, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0014 - val_loss: 0.0123
# Epoch 36/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0016    Epoch 00035: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0014 - val_loss: 0.0123
# Epoch 37/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0016    Epoch 00036: val_loss improved from 0.01228 to 0.01214, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0013 - val_loss: 0.0121
# Epoch 38/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0016    Epoch 00037: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0013 - val_loss: 0.0122
# Epoch 39/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0015    Epoch 00038: val_loss improved from 0.01214 to 0.01209, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0013 - val_loss: 0.0121
# Epoch 40/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0015    Epoch 00039: val_loss improved from 0.01209 to 0.01205, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0013 - val_loss: 0.0120
# Epoch 41/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0015    Epoch 00040: val_loss improved from 0.01205 to 0.01198, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0013 - val_loss: 0.0120
# Epoch 42/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0015    Epoch 00041: val_loss improved from 0.01198 to 0.01194, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0013 - val_loss: 0.0119
# Epoch 43/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0015    Epoch 00042: val_loss improved from 0.01194 to 0.01190, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0013 - val_loss: 0.0119
# Epoch 44/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0015    Epoch 00043: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0013 - val_loss: 0.0119
# Epoch 45/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0015    Epoch 00044: val_loss improved from 0.01190 to 0.01185, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0012 - val_loss: 0.0118
# Epoch 46/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0015    Epoch 00045: val_loss improved from 0.01185 to 0.01174, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0012 - val_loss: 0.0117
# Epoch 47/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0015    Epoch 00046: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0012 - val_loss: 0.0117
# Epoch 48/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0015    Epoch 00047: val_loss improved from 0.01174 to 0.01169, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0012 - val_loss: 0.0117
# Epoch 49/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0015    Epoch 00048: val_loss improved from 0.01169 to 0.01163, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0012 - val_loss: 0.0116
# Epoch 50/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0014    Epoch 00049: val_loss improved from 0.01163 to 0.01163, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0012 - val_loss: 0.0116
# Epoch 51/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0014    Epoch 00050: val_loss improved from 0.01163 to 0.01144, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0012 - val_loss: 0.0114
# Epoch 52/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0014    Epoch 00051: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0012 - val_loss: 0.0116
# Epoch 53/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0014    Epoch 00052: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0012 - val_loss: 0.0115
# Epoch 54/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0014    Epoch 00053: val_loss improved from 0.01144 to 0.01142, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0012 - val_loss: 0.0114
# Epoch 55/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0014    Epoch 00054: val_loss improved from 0.01142 to 0.01140, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0012 - val_loss: 0.0114
# Epoch 56/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0014    Epoch 00055: val_loss improved from 0.01140 to 0.01137, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0012 - val_loss: 0.0114
# Epoch 57/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0014    Epoch 00056: val_loss improved from 0.01137 to 0.01131, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0012 - val_loss: 0.0113
# Epoch 58/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0014    Epoch 00057: val_loss improved from 0.01131 to 0.01131, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0113
# Epoch 59/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0014    Epoch 00058: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0113
# Epoch 60/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0014    Epoch 00059: val_loss improved from 0.01131 to 0.01129, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0012 - val_loss: 0.0113
# Epoch 61/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0014    Epoch 00060: val_loss improved from 0.01129 to 0.01128, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0113
# Epoch 62/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0014    Epoch 00061: val_loss improved from 0.01128 to 0.01119, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0012 - val_loss: 0.0112
# Epoch 63/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0014    Epoch 00062: val_loss improved from 0.01119 to 0.01110, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0012 - val_loss: 0.0111
# Epoch 64/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00063: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0111
# Epoch 65/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00064: val_loss improved from 0.01110 to 0.01106, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0111
# Epoch 66/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00065: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0112
# Epoch 67/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00066: val_loss improved from 0.01106 to 0.01105, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0110
# Epoch 68/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00067: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0111
# Epoch 69/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00068: val_loss improved from 0.01105 to 0.01101, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0110
# Epoch 70/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00069: val_loss improved from 0.01101 to 0.01095, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0109
# Epoch 71/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00070: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0110
# Epoch 72/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00071: val_loss improved from 0.01095 to 0.01093, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0109
# Epoch 73/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00072: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0110
# Epoch 74/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00073: val_loss improved from 0.01093 to 0.01091, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0109
# Epoch 75/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00074: val_loss improved from 0.01091 to 0.01083, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0108
# Epoch 76/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00075: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0109
# Epoch 77/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00076: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0109
# Epoch 78/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00077: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0109
# Epoch 79/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00078: val_loss improved from 0.01083 to 0.01083, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0108
# Epoch 80/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00079: val_loss improved from 0.01083 to 0.01080, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0108
# Epoch 81/500
#  960/1966 [=============>................] - ETA: 0s - loss: 0.0013    Epoch 00080: val_loss improved from 0.01080 to 0.01079, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0108
# Epoch 82/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00081: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0109
# Epoch 83/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00082: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0108
# Epoch 84/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00083: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0109
# Epoch 85/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00084: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0108
# Epoch 86/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00085: val_loss improved from 0.01079 to 0.01071, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0107
# Epoch 87/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00086: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0107
# Epoch 88/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00087: val_loss improved from 0.01071 to 0.01071, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0107
# Epoch 89/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00088: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0107
# Epoch 90/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00089: val_loss improved from 0.01071 to 0.01070, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0107
# Epoch 91/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00090: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0107
# Epoch 92/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00091: val_loss improved from 0.01070 to 0.01070, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0107
# Epoch 93/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00092: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0108
# Epoch 94/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00093: val_loss improved from 0.01070 to 0.01068, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0107
# Epoch 95/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00094: val_loss improved from 0.01068 to 0.01067, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0107
# Epoch 96/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00095: val_loss improved from 0.01067 to 0.01065, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0106
# Epoch 97/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00096: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0107
# Epoch 98/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00097: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0107
# Epoch 99/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00098: val_loss improved from 0.01065 to 0.01064, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0106
# Epoch 100/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00099: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0107
# Epoch 101/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00100: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0107
# Epoch 102/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00101: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0107
# Epoch 103/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00102: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0107
# Epoch 104/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00103: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0107
# Epoch 105/500
# 1056/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00104: val_loss improved from 0.01064 to 0.01056, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0106
# Epoch 106/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00105: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0107
# Epoch 107/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00106: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0106
# Epoch 108/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00107: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0107
# Epoch 109/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00108: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0106
# Epoch 110/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00109: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0106
# Epoch 111/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00110: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0106
# Epoch 112/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00111: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0107
# Epoch 113/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00112: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0106
# Epoch 114/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00113: val_loss improved from 0.01056 to 0.01054, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0105
# Epoch 115/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00114: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0106
# Epoch 116/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00115: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0107
# Epoch 117/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00116: val_loss improved from 0.01054 to 0.01050, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0105
# Epoch 118/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0013    Epoch 00117: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0106
# Epoch 119/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00118: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0105
# Epoch 120/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00119: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0106
# Epoch 121/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00120: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0106
# Epoch 122/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00121: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0106
# Epoch 123/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00122: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0105
# Epoch 124/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00123: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0106
# Epoch 125/500
# 1056/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00124: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0105
# Epoch 126/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00125: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0106
# Epoch 127/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00126: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0106
# Epoch 128/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00127: val_loss improved from 0.01050 to 0.01049, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0105
# Epoch 129/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00128: val_loss improved from 0.01049 to 0.01048, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0105
# Epoch 130/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00129: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0105
# Epoch 131/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00130: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0106
# Epoch 132/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00131: val_loss improved from 0.01048 to 0.01045, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0105
# Epoch 133/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00132: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0105
# Epoch 134/500
# 1032/1966 [==============>...............] - ETA: 0s - loss: 0.0012    Epoch 00133: val_loss improved from 0.01045 to 0.01045, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0105
# Epoch 135/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00134: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0105
# Epoch 136/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00135: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0105
# Epoch 137/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00136: val_loss improved from 0.01045 to 0.01034, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0103
# Epoch 138/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00137: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0104
# Epoch 139/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00138: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0104
# Epoch 140/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00139: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0106
# Epoch 141/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00140: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0105
# Epoch 142/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00141: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0104
# Epoch 143/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00142: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0106
# Epoch 144/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00143: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0104
# Epoch 145/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00144: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0105
# Epoch 146/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00145: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0104
# Epoch 147/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00146: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0104
# Epoch 148/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00147: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0104
# Epoch 149/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00148: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0104
# Epoch 150/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00149: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0105
# Epoch 151/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00150: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0106
# Epoch 152/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00151: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0104
# Epoch 153/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00152: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0104
# Epoch 154/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00153: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0104
# Epoch 155/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00154: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0105
# Epoch 156/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00155: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0104
# Epoch 157/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00156: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0105
# Epoch 158/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00157: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0104
# Epoch 159/500
# 1056/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00158: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0105
# Epoch 160/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00159: val_loss improved from 0.01034 to 0.01030, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0103
# Epoch 161/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00160: val_loss improved from 0.01030 to 0.01030, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0103
# Epoch 162/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00161: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0104
# Epoch 163/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00162: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0104
# Epoch 164/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00163: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0104
# Epoch 165/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00164: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0105
# Epoch 166/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00165: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0105
# Epoch 167/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00166: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0103
# Epoch 168/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00167: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0104
# Epoch 169/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00168: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0104
# Epoch 170/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00169: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0103
# Epoch 171/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00170: val_loss improved from 0.01030 to 0.01027, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0103
# Epoch 172/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00171: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0104
# Epoch 173/500
# 1032/1966 [==============>...............] - ETA: 0s - loss: 0.0012    Epoch 00172: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0103
# Epoch 174/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00173: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0104
# Epoch 175/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00174: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0103
# Epoch 176/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00175: val_loss improved from 0.01027 to 0.01022, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 177/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00176: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0103
# Epoch 178/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00177: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0103
# Epoch 179/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00178: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0103
# Epoch 180/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00179: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0104
# Epoch 181/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00180: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 182/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00181: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0103
# Epoch 183/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00182: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0104
# Epoch 184/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00183: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 185/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00184: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0103
# Epoch 186/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00185: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0103
# Epoch 187/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00186: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0103
# Epoch 188/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00187: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0103
# Epoch 189/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00188: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0103
# Epoch 190/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00189: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0104
# Epoch 191/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00190: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0103
# Epoch 192/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00191: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0103
# Epoch 193/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00192: val_loss improved from 0.01022 to 0.01013, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 194/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00193: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 195/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00194: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 196/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00195: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 197/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00196: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 198/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00197: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0103
# Epoch 199/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00198: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 200/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00199: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 201/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00200: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 202/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00201: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 203/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 7.0635e-0 - ETA: 0s - loss: 0.0012    Epoch 00202: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0103
# Epoch 204/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00203: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 205/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00204: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 206/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00205: val_loss did not improve
# ...
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 214/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00213: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 215/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00214: val_loss improved from 0.01013 to 0.01004, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0100
# Epoch 216/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00215: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0103
# Epoch 217/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00216: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 218/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00217: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0103
# Epoch 219/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00218: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 220/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00219: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 221/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00220: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 222/500
# 1008/1966 [==============>...............] - ETA: 0s - loss: 0.0012    Epoch 00221: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 223/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00222: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 224/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00223: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0103
# Epoch 225/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00224: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 226/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00225: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 227/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00226: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 228/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00227: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 229/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00228: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 230/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00229: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 231/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00230: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 232/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00231: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 233/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00232: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 234/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00233: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 235/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00234: val_loss improved from 0.01004 to 0.01001, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0100
# Epoch 236/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00235: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 237/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00236: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 238/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00237: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 239/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00238: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0103
# Epoch 240/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00239: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0100
# Epoch 241/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00240: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 242/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00241: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 243/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0011    Epoch 00242: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 244/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0011    Epoch 00243: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 9.9696e-04 - val_loss: 0.0101
# Epoch 245/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00244: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 246/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00245: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 247/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00246: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 248/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00247: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 249/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00248: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 250/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00249: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 251/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00250: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 252/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00251: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 253/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00252: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 254/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00253: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 255/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00254: val_loss improved from 0.01001 to 0.00996, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0100
# Epoch 256/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00255: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0100
# Epoch 257/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00256: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 258/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00257: val_loss improved from 0.00996 to 0.00988, saving model to best_model_mlp-mimo-2.hdf5
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0099
# Epoch 259/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00258: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0099
# Epoch 260/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00259: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0100
# Epoch 261/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00260: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 262/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00261: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 263/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00262: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0100
# Epoch 264/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00263: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 265/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00264: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0100
# Epoch 266/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00265: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 267/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0011    Epoch 00266: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 9.9497e-04 - val_loss: 0.0101
# Epoch 268/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00267: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 269/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00268: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0100
# Epoch 270/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00269: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 271/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00270: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0100
# Epoch 272/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00271: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0100
# Epoch 273/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00272: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0100
# Epoch 274/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0011    Epoch 00273: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0100
# Epoch 275/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0011    Epoch 00274: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0100
# Epoch 276/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00275: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 277/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00276: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 278/500
# 1104/1966 [===============>..............] - ETA: 0s - loss: 0.0011    Epoch 00277: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 9.9929e-04 - val_loss: 0.0102
# Epoch 279/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00278: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0100
# Epoch 280/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00279: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 281/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00280: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0099
# Epoch 282/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00281: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0100
# Epoch 283/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00282: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0100
# Epoch 284/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00283: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0100
# Epoch 285/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00284: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 286/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00285: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0100
# Epoch 287/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00286: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0101
# Epoch 288/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00287: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0102
# Epoch 289/500
# 1080/1966 [===============>..............] - ETA: 0s - loss: 0.0012    Epoch 00288: val_loss did not improve
# 1966/1966 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0100
# Epoch 00288: early stopping
# Training time : 30.702352047

# %%
model = load_model('best_model_mlp-mimo-2.hdf5')

# %%
# %matplotlib inline

# %%
MAPEs = []
for day in create_date_range('2017-09-01','2017-09-5'):
    #print(day)
    results, rmse = predict_day(day,model,lookback)
    plt.figure()
    #results.DAENERGY.plot()
    #results.forecast.plot()
    y_pred = list_scalers['DAENERGY'].inverse_transform(results.forecast.values.reshape(-1,1))
    y_true = list_scalers['DAENERGY'].inverse_transform(results.DAENERGY.values.reshape(-1,1))
    MAPEs.append(MAPE(y_true, y_pred))
    y_rt = list_scalers['RTENERGY'].inverse_transform(results.RTENERGY.values.reshape(-1,1))
    X  = np.linspace(0,24,24)
    plt.plot(X,y_pred, label='forecast')
    plt.plot(X,y_true, label='actual DA')
    #plt.plot(X,y_rt, label='RT')
    plt.legend(loc='best')
    y_true =y_true.reshape(24)
    y_pred = y_pred.reshape(24)
    y_rt = y_rt.reshape(24)
    mask = ((y_rt > y_true) & (y_pred > y_true)) | ((y_rt < y_true) & (y_pred < y_true))
    plt.fill_between(X,y_pred.reshape(24), y_true.reshape(24), where=mask, alpha = 0.5)


plt.figure()
plt.plot(MAPEs)
plt.title('MAPE')
plt.xlabel('time')
plt.ylabel('MAPE')
print('MAPE mean:{:.2f}'.format(np.array(MAPEs).mean()))
# Out:
# MAPE mean:6.02

# %%
MAPEs=[]
for day in create_date_range('2017-10-01','2017-10-05'):
    results, rmse = predict_day(day,model,lookback)
    plt.figure()
    #results.DAENERGY.plot()
    #results.forecast.plot()
    y_pred = list_scalers['DAENERGY'].inverse_transform(results.forecast.values.reshape(-1,1))
    y_true = list_scalers['DAENERGY'].inverse_transform(results.DAENERGY.values.reshape(-1,1))
    MAPEs.append(MAPE(y_true, y_pred))
    y_rt = list_scalers['RTENERGY'].inverse_transform(results.RTENERGY.values.reshape(-1,1))
    X  = np.linspace(0,24,24)
    plt.plot(X,y_pred, label='forecast')
    plt.plot(X,y_true, label='actual DA')
    #plt.plot(X,y_rt, label='RT')
    plt.legend(loc='best')
    plt.title(day)
    y_true =y_true.reshape(24)
    y_pred = y_pred.reshape(24)
    y_rt = y_rt.reshape(24)
    mask = ((y_rt > y_true) & (y_pred > y_true)) | ((y_rt < y_true) & (y_pred < y_true))
    plt.fill_between(X,y_pred.reshape(24), y_true.reshape(24), where=mask, alpha = 0.5)
plt.figure()
plt.plot(MAPEs)
plt.title('MAPE')
plt.xlabel('time')
plt.ylabel('MAPE')
print('MAPE mean:{:.2f}'.format(np.array(MAPEs).mean()))
# Out:
# MAPE mean:8.60

# %%
MAPEs=[]
day ='2017-10-01'
results, rmse = predict_day(day,model,lookback)
plt.figure(figsize = (15,10))
#results.DAENERGY.plot()
#results.forecast.plot()
#results.RTENERGY.plot()
y_pred = list_scalers['DAENERGY'].inverse_transform(results.forecast.values.reshape(-1,1))
y_true = list_scalers['DAENERGY'].inverse_transform(results.DAENERGY.values.reshape(-1,1))
y_rt = list_scalers['RTENERGY'].inverse_transform(results.RTENERGY.values.reshape(-1,1))
y_true =y_true.reshape(24)
y_pred = y_pred.reshape(24)
y_rt = y_rt.reshape(24)
mask = ((y_rt > y_true) & (y_pred > y_true)) | ((y_rt < y_true) & (y_pred < y_true))



ci = get_ci(day,model)
y_ci_u = list_scalers['DAENERGY'].inverse_transform(ci.forecast_high.values.reshape(-1,1)).reshape(24)
y_ci_l = list_scalers['DAENERGY'].inverse_transform(ci.forecast_low.values.reshape(-1,1)).reshape(24)

X  = np.linspace(0,24,24)
plt.plot(X,y_pred, label='forecast')
plt.plot(X,y_true, label = 'actual')
plt.plot(X,y_rt, label = 'RT')
#plt.plot(X,y_ci_u, '.',label = 'upper_level')
#plt.plot(X,y_ci_l, '.',label = 'lower_level')
plt.xlabel('time of day')
plt.ylabel('ENERGY PRICE')
plt.legend()
plt.title(day)
plt.fill_between(X,y_pred, y_true, where=mask, alpha = 0.5)
plt.fill_between(X,y_ci_u, y_ci_l, color = 'red',alpha = 0.5)



MAPEs.append(MAPE(y_true, y_pred))

print('MAPE mean:{:.2f}'.format(np.array(MAPEs).mean()))
# Out:
# MAPE mean:8.71

# %%
def get_ci(date_predict,model):
    date_p = datetime.datetime.strptime(date_predict, "%Y-%m-%d").date()
    date_limit = (date_p - datetime.timedelta(days=1)).strftime('%Y-%m-%d')
    date_start = (date_p - datetime.timedelta(days=42)).strftime('%Y-%m-%d')

    df_predict_low = df.copy()
    df_predict_low = df_predict_low[:date_predict]

    df_predict_low = df_predict_low.drop(['TRADEDATE', 'RTENERGY'], axis=1)
    df_predict_low = df_predict_low[date_start:]
    df_predict_high = df_predict_low.copy()
    
    df_predict_low.LOAD = df_predict_low.LOAD*0.95
    df_predict_high.LOAD = df_predict_high.LOAD*1.05
    
    df_predict_low.ISOWIND = df_predict_low.ISOWIND*1.05
    df_predict_high.ISOWIND = df_predict_high.ISOWIND*0.95
    
    df_predict_low.OUTAGE = df_predict_low.OUTAGE*0.95
    df_predict_high.OUTAGE = df_predict_high.OUTAGE*1.05
    
    df_predict_low.Temp_C_0 = df_predict_low.Temp_C_0*0.95
    df_predict_high.Temp_C_0 = df_predict_high.Temp_C_0*1.05
    df_predict_low.Temp_C_1 = df_predict_low.Temp_C_1*0.95
    df_predict_high.Temp_C_1 = df_predict_high.Temp_C_1*1.05
    df_predict_low.Temp_C_2 = df_predict_low.Temp_C_2*0.95
    df_predict_high.Temp_C_2 = df_predict_high.Temp_C_2*1.05
    df_predict_low.Temp_C_3 = df_predict_low.Temp_C_3*0.95
    df_predict_high.Temp_C_3 = df_predict_high.Temp_C_3*1.05
    
    y_low = df_predict_low.pop('DAENERGY').values
    y_high = df_predict_high.pop('DAENERGY').values
    
    X_low = df_predict_low.values[:,1:]
    X_high = df_predict_high.values[:,1:]
    
    #X,y = data_lstm(X,y,lookback)
    X_low,y_low = data_mimo(X_low,y_low,lookback)
    X_high,y_high = data_mimo(X_high,y_high,lookback)
    
    input_p_low = X_low[-1:]
    input_p_high = X_high[-1:]
    
    pred_low = model.predict(input_p_low,batch_size=1)
    pred_high = model.predict(input_p_high,batch_size=1)

    results = df[date_predict].copy()
    # pred_ada = model.predict(input_p.values)
    results['forecast_low'] = pred_low[0]
    results['forecast_high'] = pred_high[0]
    
    return results

# %%
ci = get_ci('2017-10-01',model)
y_ci_u = list_scalers['DAENERGY'].inverse_transform(ci.forecast_high.values.reshape(-1,1))
y_ci_l = list_scalers['DAENERGY'].inverse_transform(ci.forecast_low.values.reshape(-1,1))

# %%
X  = np.linspace(0,24,24)
plt.plot(X,y_pred, label='forecast')
plt.plot(X,y_true, label = 'actual')
plt.plot(X,y_ci_u, '.',label = 'upper_level')
plt.plot(X,y_ci_l, '.',label = 'lower_level')
