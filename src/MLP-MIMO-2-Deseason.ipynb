# %%
from process_data import clean_data, create_index, pivot_data, clean_data2
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, LSTM, Dropout, Activation, TimeDistributed
from keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
from keras.models import load_model
import matplotlib.pyplot as plt
import time
import datetime
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

# %%
def data_mimo(X,y,lookback=1):
    newX = []
    newY = []
    for i in range(len(y)-lookback):
        newX.append(X[i:i+1+lookback,:])
        newY.append(y[i:i+1+lookback])
    return np.array(newX), np.array(newY)



def mlp(lookback,num_features):
    model = Sequential()
    model.add(TimeDistributed(Dense(2*lookback+1,activation='tanh'), input_shape=(lookback+1,num_features)))
    model.add(Dropout(0.1))
    model.add(TimeDistributed(Dense(lookback+1,activation='tanh')))
    model.add(Dropout(0.1))
    model.add(TimeDistributed(Dense(1,activation='linear')))
    model.compile(loss='mean_squared_error', optimizer='adam')
    model.summary()
    return model


def train_rnn(df,date_predict,lookback,epochs=100):
    #Preparting data to Train
    print('Preparing data to Train')
    date_p = datetime.datetime.strptime(date_predict, "%Y-%m-%d").date()
    date_limit = (date_p - datetime.timedelta(days=1)).strftime('%Y-%m-%d')
    date_start = (date_p - datetime.timedelta(days=90+lookback//24)).strftime('%Y-%m-%d')
    sk = df[:date_limit].copy()
    print(sk.shape)
    sk = sk.drop(['TRADEDATE', 'RTENERGY'], axis=1)

    #sk.hourofday = sk.hourofday.dt.seconds/3600
    sk = sk[date_start:]
    #sk = sk[24:]
    print('Shape os SK:',sk.shape)
    y = sk.pop('DAENERGY').values
    X = sk.values[:,1:]
    X, y = data_mimo(X,y,lookback)
    y = y.reshape(len(y),y.shape[1],1)
    print('Shape of X',X.shape)
    #X = X[1:]
    #y = y[1:]
    print('Shape of X',X.shape)
    print('YYYY')
    print(y.shape)
    
    model = mlp(lookback,X.shape[2])
    #model = create_rnn(lookback,X.shape[2])

    #X = X.reshape(X.shape[0],X.shape[1],1)
    filepath="weights-improvement-{epoch:02d}-{val_loss:.2f}.hdf5"
    filepath="best_model_mlp-mimo-2.hdf5"

    checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
    early_stop = EarlyStopping(monitor='val_loss', patience=30, verbose=1)
    tensorboard = TensorBoard(log_dir='./logs/mlp'+str(time.time()), 
                              histogram_freq=0, 
                              batch_size=24, 
                              write_graph=True, 
                              write_grads=False, 
                              write_images=True, 
                              )
    # #Training Model
    model.fit(
        X,
        y,
        batch_size=24,  #168, 
        epochs=epochs,
        shuffle = False,
        validation_split=0.1, callbacks=[tensorboard, checkpoint, early_stop])  #0.0857 #0.05 #0.1

    #preparing data to Predict
    return model, X, y

def predict_day(date_predict,model,lookback=168):
    date_p = datetime.datetime.strptime(date_predict, "%Y-%m-%d").date()
    date_limit = (date_p - datetime.timedelta(days=1)).strftime('%Y-%m-%d')
    date_start = (date_p - datetime.timedelta(days=42)).strftime('%Y-%m-%d')

    df_predict = df.copy()
    df_predict = df_predict[:date_predict]

    df_predict = df_predict.drop(['TRADEDATE', 'RTENERGY'], axis=1)

    #df_predict.hourofday = df_predict.hourofday.dt.seconds/3600
    df_predict = df_predict[date_start:]
    y = df_predict.pop('DAENERGY').values
    X = df_predict.values[:,1:]
    #X,y = data_lstm(X,y,lookback)
    X,y = data_mimo(X,y,lookback)
    input_p = X[-24:]   #-24
    input_p = X[-1:]
    pred = model.predict(input_p,batch_size=1)

    results = df[date_predict].copy()
    # pred_ada = model.predict(input_p.values)
    results['forecast'] = pred[0]
    RMSE = get_rmse(results['DAENERGY'].values, pred)
    return results, RMSE

def plot_results(results,date_predict):
    RMSE = get_rmse(results['DAENERGY'], results['forecast'])
    fig, ax = plt.subplots(figsize=(9,4))
    # npre = 24
    ax.set(title='DAENERGY '+ 'RMSE: {:.3f} for {}'.format(RMSE, date_predict), xlabel='Date', ylabel='Price DAENERGY')
    #
    # # Plot data points
    results['DAENERGY'].plot(ax=ax, style='o', label='Observed')
    #
    # # Plot predictions
    results.forecast.plot(ax=ax, style='r--', label='forecast')
    # #ci = predict_ci.loc[date_predict]
    # #ax.fill_between(ci.index, ci.iloc[:,0], ci.iloc[:,1], color='r', alpha=0.1)
    legend = ax.legend(loc='lower right')


def get_rmse(pred,real):
    return np.sqrt(((pred-real)**2).sum()/pred.shape[0])

def create_date_range(start_date, end_date):
    start_dt = datetime.datetime.strptime(start_date, "%Y-%m-%d").date()
    end_dt = datetime.datetime.strptime(end_date, "%Y-%m-%d").date()
    dates = []
    cur_dt = start_dt
    dates.append(start_date)
    while cur_dt<end_dt:
        cur_dt = cur_dt + datetime.timedelta(days=1)
        dates.append(cur_dt.strftime('%Y-%m-%d'))
    return dates


def create_features(df):
    df = df.copy()
    features = ['Ph-1', 'Ph-2', 'Ph-3', 'Ph-24', 'Ph-25', 'Ph-48', 'Ph-49',
                'Ph-72','Ph-73', 'Ph-96', 'Ph-97', 'Ph-120', 'Ph-121', 'Ph-144',
                'Ph-145', 'Ph-168']
    deltas = [1, 2, 3, 24, 25, 48, 49, 72, 73, 96, 97, 120, 121, 144, 145, 168]

    for col, shift in zip(features, deltas):
        df[col] = df.DAENERGY.shift(shift)
    return df

def create_rollings(df):
    df = df.copy()
    means_cols = ['mean_3','mean_6','mean_9','mean_12','mean_24']
    means_values = [3,6,9,12,24]
    
    for col, val in zip(means_cols, means_values):
        df[col] = pd.Series.rolling(df.DAENERGY, window=val, center = False).mean()
        df[col] = df[col].shift(24)
    
    #df['p_1'] = df.DAENERGY.shift(1)
    df['p_24'] = df.DAENERGY.shift(24)
    df['p_48'] = df.DAENERGY.shift(48)
    return df        

def MAPE(y_true, y_pred):
    return 1.0/len(y_true)*(np.abs((y_true-y_pred))/y_true*100).sum()

from keras.optimizers import RMSprop, Adam, Adadelta

# %%
df = pivot_data('../data/Data.txt')
#scaler = MinMaxScaler(feature_range=(-1,1)).fit(df.DAENERGY)
#df.DAENERGY = scaler.transform(df.DAENERGY)
df = clean_data(df)
df = create_index(df)
df2 = pivot_data('../data/FurtherBack.txt','2017-05-15','2017-07-07')
df2 = clean_data2(df2)
df2 = create_index(df2)
#df = pd.concat([df2,df])
df = pd.concat([df2[:'2017-07-05'],df['2017-07-06':]])
df = df.reindex(pd.date_range(df.index[0],df.index[-1],freq='H'))

df = create_rollings(df)
df = df.dropna()

wdf = pd.read_csv('../data/wstation.csv', delim_whitespace=True)
temp_cols = []
cols = df.columns.values
for col in cols:
    if len(col)==4 and col not in ['LOAD', 'p_48', 'p_72']:
        temp_cols.append(col)
        
wdf = wdf.drop_duplicates(subset = ['CALL'])

temps = pd.DataFrame(temp_cols)
temps.columns = ['CALL']
result = pd.merge(temps, wdf, how='left', on=['CALL'])
result = result[['CALL','LAT','LON']]
result = result.dropna()

from sklearn.cluster import KMeans
clusters = KMeans(n_clusters = 4).fit(result[['LAT','LON']])

result['Cluster'] = clusters.labels_

df['Temp_C_0']=df[result[result.Cluster==0]['CALL']].mean(axis=1)
df['Temp_C_1']=df[result[result.Cluster==1]['CALL']].mean(axis=1)
df['Temp_C_2']=df[result[result.Cluster==2]['CALL']].mean(axis=1)
df['Temp_C_3']=df[result[result.Cluster==3]['CALL']].mean(axis=1)

df = df.drop(temp_cols, axis=1)


list_scalers = dict()
for c in df.columns.values:
    list_scalers[c] = MinMaxScaler()
    list_scalers[c].fit(df[c].values.reshape(-1,1))
    df[c] = list_scalers[c].transform(df[c].values.reshape(-1,1))

print('Deseasonalizing the data...') 

import statsmodels.api as sm
decomposition = sm.tsa.seasonal_decompose(df.DAENERGY)
df.DAENERGY = df.DAENERGY - decomposition.seasonal

print('Training the model...')

lookback=23#72#48#168
# Out:
# Deseasonalizing the data...
# Training the model...

# %%
lookback=71

# %%
#df.DAENERGY = list_scalers['DAENERGY'].inverse_transform(df.DAENERGY.values)
start = time.time()
model, X, y = train_rnn(df,'2017-10-01',lookback=71,epochs=1000)
print('Training time : {}'.format(time.time() - start))
# Out:
# Preparing data to Train
# (3287, 18)
# ('Shape os SK:', (2208, 16))
# ('Shape of X', (2137, 72, 14))
# ('Shape of X', (2137, 72, 14))
# YYYY
# (2137, 72, 1)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed_43 (TimeDis (None, 72, 143)           2145
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 72, 143)           0
# _________________________________________________________________
# time_distributed_44 (TimeDis (None, 72, 72)            10368
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 72, 72)            0
# _________________________________________________________________
# time_distributed_45 (TimeDis (None, 72, 1)             73
# =================================================================
# Total params: 12,586
# Trainable params: 12,586
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1923 samples, validate on 214 samples
# Epoch 1/1000
# 1320/1923 [===================>..........] - ETA: 0s - loss: 0.0221Epoch 00000: val_loss improved from inf to 0.02493, saving model to best_model_mlp-mimo-2.hdf5
# 1923/1923 [==============================] - 0s - loss: 0.0182 - val_loss: 0.0249
# Epoch 2/1000
# 1344/1923 [===================>..........] - ETA: 0s - loss: 0.0092Epoch 00001: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0084 - val_loss: 0.0254
# Epoch 3/1000
# 1320/1923 [===================>..........] - ETA: 0s - loss: 0.0067Epoch 00002: val_loss improved from 0.02493 to 0.02413, saving model to best_model_mlp-mimo-2.hdf5
# 1923/1923 [==============================] - 0s - loss: 0.0057 - val_loss: 0.0241
# Epoch 4/1000
# 1368/1923 [====================>.........] - ETA: 0s - loss: 0.0046Epoch 00003: val_loss improved from 0.02413 to 0.02360, saving model to best_model_mlp-mimo-2.hdf5
# 1923/1923 [==============================] - 0s - loss: 0.0041 - val_loss: 0.0236
# Epoch 5/1000
# 1464/1923 [=====================>........] - ETA: 0s - loss: 0.0043Epoch 00004: val_loss improved from 0.02360 to 0.01890, saving model to best_model_mlp-mimo-2.hdf5
# 1923/1923 [==============================] - 0s - loss: 0.0039 - val_loss: 0.0189
# Epoch 6/1000
# 1488/1923 [======================>.......] - ETA: 0s - loss: 0.0026Epoch 00005: val_loss improved from 0.01890 to 0.01819, saving model to best_model_mlp-mimo-2.hdf5
# 1923/1923 [==============================] - 0s - loss: 0.0025 - val_loss: 0.0182
# Epoch 7/1000
# 1464/1923 [=====================>........] - ETA: 0s - loss: 0.0025Epoch 00006: val_loss improved from 0.01819 to 0.01768, saving model to best_model_mlp-mimo-2.hdf5
# 1923/1923 [==============================] - 0s - loss: 0.0024 - val_loss: 0.0177
# Epoch 8/1000
# 1392/1923 [====================>.........] - ETA: 0s - loss: 0.0024Epoch 00007: val_loss improved from 0.01768 to 0.01720, saving model to best_model_mlp-mimo-2.hdf5
# 1923/1923 [==============================] - 0s - loss: 0.0022 - val_loss: 0.0172
# Epoch 9/1000
# 1488/1923 [======================>.......] - ETA: 0s - loss: 0.0022Epoch 00008: val_loss improved from 0.01720 to 0.01701, saving model to best_model_mlp-mimo-2.hdf5
# 1923/1923 [==============================] - 0s - loss: 0.0020 - val_loss: 0.0170
# Epoch 10/1000
# 1440/1923 [=====================>........] - ETA: 0s - loss: 0.0020   Epoch 00009: val_loss improved from 0.01701 to 0.01683, saving model to best_model_mlp-mimo-2.hdf5
# 1923/1923 [==============================] - 0s - loss: 0.0019 - val_loss: 0.0168
# Epoch 11/1000
# 1488/1923 [======================>.......] - ETA: 0s - loss: 0.0020   Epoch 00010: val_loss improved from 0.01683 to 0.01679, saving model to best_model_mlp-mimo-2.hdf5
# 1923/1923 [==============================] - 0s - loss: 0.0018 - val_loss: 0.0168
# Epoch 12/1000
# 1440/1923 [=====================>........] - ETA: 0s - loss: 0.0019   Epoch 00011: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0018 - val_loss: 0.0170
# Epoch 13/1000
# 1464/1923 [=====================>........] - ETA: 0s - loss: 0.0019   Epoch 00012: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0017 - val_loss: 0.0171
# Epoch 14/1000
# 1512/1923 [======================>.......] - ETA: 0s - loss: 0.0018   Epoch 00013: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0017 - val_loss: 0.0172
# Epoch 15/1000
# 1488/1923 [======================>.......] - ETA: 0s - loss: 0.0018   Epoch 00014: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0017 - val_loss: 0.0172
# Epoch 16/1000
# 1440/1923 [=====================>........] - ETA: 0s - loss: 0.0018   Epoch 00015: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0017 - val_loss: 0.0172
# Epoch 17/1000
# 1488/1923 [======================>.......] - ETA: 0s - loss: 0.0017   Epoch 00016: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0016 - val_loss: 0.0171
# Epoch 18/1000
# 1464/1923 [=====================>........] - ETA: 0s - loss: 0.0017   Epoch 00017: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0016 - val_loss: 0.0170
# Epoch 19/1000
# 1488/1923 [======================>.......] - ETA: 0s - loss: 0.0017   Epoch 00018: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0016 - val_loss: 0.0169
# Epoch 20/1000
# 1512/1923 [======================>.......] - ETA: 0s - loss: 0.0017   Epoch 00019: val_loss improved from 0.01679 to 0.01673, saving model to best_model_mlp-mimo-2.hdf5
# 1923/1923 [==============================] - 0s - loss: 0.0016 - val_loss: 0.0167
# Epoch 21/1000
# 1464/1923 [=====================>........] - ETA: 0s - loss: 0.0017   Epoch 00020: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0016 - val_loss: 0.0168
# Epoch 22/1000
# 1440/1923 [=====================>........] - ETA: 0s - loss: 0.0016   Epoch 00021: val_loss improved from 0.01673 to 0.01671, saving model to best_model_mlp-mimo-2.hdf5
# 1923/1923 [==============================] - 0s - loss: 0.0016 - val_loss: 0.0167
# Epoch 23/1000
# 1488/1923 [======================>.......] - ETA: 0s - loss: 0.0016   Epoch 00022: val_loss improved from 0.01671 to 0.01667, saving model to best_model_mlp-mimo-2.hdf5
# 1923/1923 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0167
# Epoch 24/1000
# 1464/1923 [=====================>........] - ETA: 0s - loss: 0.0016   Epoch 00023: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0167
# Epoch 25/1000
# 1440/1923 [=====================>........] - ETA: 0s - loss: 0.0016   Epoch 00024: val_loss improved from 0.01667 to 0.01666, saving model to best_model_mlp-mimo-2.hdf5
# 1923/1923 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0167
# Epoch 26/1000
# 1512/1923 [======================>.......] - ETA: 0s - loss: 0.0016   Epoch 00025: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0167
# Epoch 27/1000
# 1440/1923 [=====================>........] - ETA: 0s - loss: 0.0016   Epoch 00026: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0167
# Epoch 28/1000
# 1488/1923 [======================>.......] - ETA: 0s - loss: 0.0016   Epoch 00027: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0167
# Epoch 29/1000
# 1464/1923 [=====================>........] - ETA: 0s - loss: 0.0016   Epoch 00028: val_loss improved from 0.01666 to 0.01665, saving model to best_model_mlp-mimo-2.hdf5
# 1923/1923 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0166
# Epoch 30/1000
# 1488/1923 [======================>.......] - ETA: 0s - loss: 0.0016   Epoch 00029: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0167
# Epoch 31/1000
# 1488/1923 [======================>.......] - ETA: 0s - loss: 0.0016   Epoch 00030: val_loss improved from 0.01665 to 0.01664, saving model to best_model_mlp-mimo-2.hdf5
# 1923/1923 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0166
# Epoch 32/1000
# 1488/1923 [======================>.......] - ETA: 0s - loss: 0.0016   Epoch 00031: val_loss improved from 0.01664 to 0.01653, saving model to best_model_mlp-mimo-2.hdf5
# 1923/1923 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0165
# Epoch 33/1000
# 1440/1923 [=====================>........] - ETA: 0s - loss: 0.0016   Epoch 00032: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0165
# Epoch 34/1000
# 1488/1923 [======================>.......] - ETA: 0s - loss: 0.0016   Epoch 00033: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0166
# Epoch 35/1000
# 1488/1923 [======================>.......] - ETA: 0s - loss: 0.0016   Epoch 00034: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0165
# Epoch 36/1000
# 1464/1923 [=====================>........] - ETA: 0s - loss: 0.0016   Epoch 00035: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0166
# Epoch 37/1000
# 1464/1923 [=====================>........] - ETA: 0s - loss: 0.0017   Epoch 00036: val_loss improved from 0.01653 to 0.01644, saving model to best_model_mlp-mimo-2.hdf5
# 1923/1923 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0164
# Epoch 38/1000
# 1488/1923 [======================>.......] - ETA: 0s - loss: 0.0017Epoch 00037: val_loss improved from 0.01644 to 0.01632, saving model to best_model_mlp-mimo-2.hdf5
# 1923/1923 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0163
# Epoch 39/1000
# 1464/1923 [=====================>........] - ETA: 0s - loss: 0.0017Epoch 00038: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0164
# Epoch 40/1000
# 1464/1923 [=====================>........] - ETA: 0s - loss: 0.0016Epoch 00039: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0165
# Epoch 41/1000
# 1488/1923 [======================>.......] - ETA: 0s - loss: 0.0017Epoch 00040: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0166
# Epoch 42/1000
# 1440/1923 [=====================>........] - ETA: 0s - loss: 0.0017Epoch 00041: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0165
# Epoch 43/1000
# 1512/1923 [======================>.......] - ETA: 0s - loss: 0.0016Epoch 00042: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0168
# Epoch 44/1000
# 1488/1923 [======================>.......] - ETA: 0s - loss: 0.0017Epoch 00043: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0016 - val_loss: 0.0171
# Epoch 45/1000
# 1440/1923 [=====================>........] - ETA: 0s - loss: 0.0017Epoch 00044: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0016 - val_loss: 0.0172
# Epoch 46/1000
# 1488/1923 [======================>.......] - ETA: 0s - loss: 0.0018Epoch 00045: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0016 - val_loss: 0.0171
# Epoch 47/1000
# 1488/1923 [======================>.......] - ETA: 0s - loss: 0.0017Epoch 00046: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0016 - val_loss: 0.0176
# Epoch 48/1000
# 1464/1923 [=====================>........] - ETA: 0s - loss: 0.0017Epoch 00047: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0016 - val_loss: 0.0186
# Epoch 49/1000
# 1440/1923 [=====================>........] - ETA: 0s - loss: 0.0017Epoch 00048: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0016 - val_loss: 0.0188
# Epoch 50/1000
# 1512/1923 [======================>.......] - ETA: 0s - loss: 0.0017Epoch 00049: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0016 - val_loss: 0.0193
# Epoch 51/1000
# 1488/1923 [======================>.......] - ETA: 0s - loss: 0.0017Epoch 00050: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0016 - val_loss: 0.0195
# Epoch 52/1000
# 1464/1923 [=====================>........] - ETA: 0s - loss: 0.0017Epoch 00051: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0016 - val_loss: 0.0198
# Epoch 53/1000
# 1464/1923 [=====================>........] - ETA: 0s - loss: 0.0016Epoch 00052: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0016 - val_loss: 0.0193
# Epoch 54/1000
# 1440/1923 [=====================>........] - ETA: 0s - loss: 0.0016Epoch 00053: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0016 - val_loss: 0.0187
# Epoch 55/1000
# 1464/1923 [=====================>........] - ETA: 0s - loss: 0.0016Epoch 00054: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0183
# Epoch 56/1000
# 1488/1923 [======================>.......] - ETA: 0s - loss: 0.0017Epoch 00055: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0016 - val_loss: 0.0190
# Epoch 57/1000
# 1416/1923 [=====================>........] - ETA: 0s - loss: 0.0018Epoch 00056: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0016 - val_loss: 0.0198
# Epoch 58/1000
# 1440/1923 [=====================>........] - ETA: 0s - loss: 0.0017Epoch 00057: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0017 - val_loss: 0.0209
# Epoch 59/1000
# 1488/1923 [======================>.......] - ETA: 0s - loss: 0.0016Epoch 00058: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0016 - val_loss: 0.0198
# Epoch 60/1000
# 1440/1923 [=====================>........] - ETA: 0s - loss: 0.0015Epoch 00059: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0198
# Epoch 61/1000
# 1464/1923 [=====================>........] - ETA: 0s - loss: 0.0015Epoch 00060: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0177
# Epoch 62/1000
# 1464/1923 [=====================>........] - ETA: 0s - loss: 0.0014   Epoch 00061: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0014 - val_loss: 0.0188
# Epoch 63/1000
# 1464/1923 [=====================>........] - ETA: 0s - loss: 0.0014Epoch 00062: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0014 - val_loss: 0.0180
# Epoch 64/1000
# 1440/1923 [=====================>........] - ETA: 0s - loss: 0.0014Epoch 00063: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0014 - val_loss: 0.0184
# Epoch 65/1000
# 1464/1923 [=====================>........] - ETA: 0s - loss: 0.0014Epoch 00064: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0014 - val_loss: 0.0189
# Epoch 66/1000
# 1464/1923 [=====================>........] - ETA: 0s - loss: 0.0014Epoch 00065: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0014 - val_loss: 0.0177
# Epoch 67/1000
# 1488/1923 [======================>.......] - ETA: 0s - loss: 0.0014   Epoch 00066: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0014 - val_loss: 0.0199
# Epoch 68/1000
# 1440/1923 [=====================>........] - ETA: 0s - loss: 0.0016Epoch 00067: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0188
# Epoch 69/1000
# 1416/1923 [=====================>........] - ETA: 0s - loss: 0.0015Epoch 00068: val_loss did not improve
# 1923/1923 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0206
# Epoch 00068: early stopping
# Training time : 11.4670360088

# %%
model = load_model('best_model_mlp-mimo-2.hdf5')

# %%
# %matplotlib inline

# %%
MAPEs = []
for day in create_date_range('2017-09-01','2017-09-5'):
    #print(day)
    results, rmse = predict_day(day,model,lookback)
    plt.figure()
    #results.DAENERGY.plot()
    #results.forecast.plot()
    y_pred = list_scalers['DAENERGY'].inverse_transform(results.forecast.values.reshape(-1,1)+decomposition.seasonal['2017-09-04'].values.reshape(-1,1))
    y_true = list_scalers['DAENERGY'].inverse_transform(results.DAENERGY.values.reshape(-1,1)+decomposition.seasonal['2017-09-04'].values.reshape(-1,1))
    MAPEs.append(MAPE(y_true, y_pred))
    y_rt = list_scalers['RTENERGY'].inverse_transform(results.RTENERGY.values.reshape(-1,1))
    X  = np.linspace(0,24,24)
    plt.plot(X,y_pred, label='forecast')
    plt.plot(X,y_true, label='actual DA')
    #plt.plot(X,y_rt, label='RT')
    plt.legend(loc='best')
    y_true =y_true.reshape(24)
    y_pred = y_pred.reshape(24)
    y_rt = y_rt.reshape(24)
    mask = ((y_rt > y_true) & (y_pred > y_true)) | ((y_rt < y_true) & (y_pred < y_true))
    plt.fill_between(X,y_pred.reshape(24), y_true.reshape(24), where=mask, alpha = 0.5)


plt.figure()
plt.plot(MAPEs)
plt.title('MAPE')
plt.xlabel('time')
plt.ylabel('MAPE')
print('MAPE mean:{:.2f}'.format(np.array(MAPEs).mean()))
# Out:
# MAPE mean:32.10

# %%
MAPEs=[]
for day in create_date_range('2017-10-01','2017-10-05'):
    results, rmse = predict_day(day,model,lookback)
    plt.figure()
    #results.DAENERGY.plot()
    #results.forecast.plot()
    y_pred = list_scalers['DAENERGY'].inverse_transform(results.forecast.values.reshape(-1,1)+decomposition.seasonal['2017-09-04'].values.reshape(-1,1))
    y_true = list_scalers['DAENERGY'].inverse_transform(results.DAENERGY.values.reshape(-1,1)+decomposition.seasonal['2017-09-04'].values.reshape(-1,1))
    MAPEs.append(MAPE(y_true, y_pred))
    y_rt = list_scalers['RTENERGY'].inverse_transform(results.RTENERGY.values.reshape(-1,1))
    X  = np.linspace(0,24,24)
    plt.plot(X,y_pred, label='forecast')
    plt.plot(X,y_true, label='actual DA')
    #plt.plot(X,y_rt, label='RT')
    plt.legend(loc='best')
    plt.title(day)
    y_true =y_true.reshape(24)
    y_pred = y_pred.reshape(24)
    y_rt = y_rt.reshape(24)
    mask = ((y_rt > y_true) & (y_pred > y_true)) | ((y_rt < y_true) & (y_pred < y_true))
    plt.fill_between(X,y_pred.reshape(24), y_true.reshape(24), where=mask, alpha = 0.5)
plt.figure()
plt.plot(MAPEs)
plt.title('MAPE')
plt.xlabel('time')
plt.ylabel('MAPE')
print('MAPE mean:{:.2f}'.format(np.array(MAPEs).mean()))
# Out:
# MAPE mean:27.00

# %%
MAPEs=[]
day ='2017-09-18'
results, rmse = predict_day(day,model,lookback)
plt.figure(figsize = (15,10))
#results.DAENERGY.plot()
#results.forecast.plot()
#results.RTENERGY.plot()
y_pred = list_scalers['DAENERGY'].inverse_transform(results.forecast.values.reshape(-1,1)+decomposition.seasonal['2017-09-04'].values.reshape(-1,1))
y_true = list_scalers['DAENERGY'].inverse_transform(results.DAENERGY.values.reshape(-1,1)+decomposition.seasonal['2017-09-04'].values.reshape(-1,1))
y_rt = list_scalers['RTENERGY'].inverse_transform(results.RTENERGY.values.reshape(-1,1))
y_true =y_true.reshape(24)
y_pred = y_pred.reshape(24)
y_rt = y_rt.reshape(24)
mask = ((y_rt > y_true) & (y_pred > y_true)) | ((y_rt < y_true) & (y_pred < y_true))



ci = get_ci(day,model)
y_ci_u = list_scalers['DAENERGY'].inverse_transform(ci.forecast_high.values.reshape(-1,1)+decomposition.seasonal['2017-09-04'].values.reshape(-1,1)).reshape(24)
y_ci_l = list_scalers['DAENERGY'].inverse_transform(ci.forecast_low.values.reshape(-1,1)+decomposition.seasonal['2017-09-04'].values.reshape(-1,1)).reshape(24)

X  = np.linspace(0,24,24)
plt.plot(X,y_pred, label='forecast')
plt.plot(X,y_true, label = 'actual')
plt.plot(X,y_rt, label = 'RT')
#plt.plot(X,y_ci_u, '.',label = 'upper_level')
#plt.plot(X,y_ci_l, '.',label = 'lower_level')
plt.xlabel('time of day')
plt.ylabel('ENERGY PRICE')
plt.legend()
plt.title(day)
plt.fill_between(X,y_pred, y_true, where=mask, alpha = 0.5)
plt.fill_between(X,y_ci_u, y_ci_l, color = 'red',alpha = 0.5)



MAPEs.append(MAPE(y_true, y_pred))

print('MAPE mean:{:.2f}'.format(np.array(MAPEs).mean()))
# Out:
# MAPE mean:10.62

# %%
def get_ci(date_predict,model):
    date_p = datetime.datetime.strptime(date_predict, "%Y-%m-%d").date()
    date_limit = (date_p - datetime.timedelta(days=1)).strftime('%Y-%m-%d')
    date_start = (date_p - datetime.timedelta(days=42)).strftime('%Y-%m-%d')

    df_predict_low = df.copy()
    df_predict_low = df_predict_low[:date_predict]

    df_predict_low = df_predict_low.drop(['TRADEDATE', 'RTENERGY'], axis=1)
    df_predict_low = df_predict_low[date_start:]
    df_predict_high = df_predict_low.copy()
    
    df_predict_low.LOAD = df_predict_low.LOAD*0.95
    df_predict_high.LOAD = df_predict_high.LOAD*1.05
    
    df_predict_low.ISOWIND = df_predict_low.ISOWIND*1.05
    df_predict_high.ISOWIND = df_predict_high.ISOWIND*0.95
    
    df_predict_low.OUTAGE = df_predict_low.OUTAGE*0.95
    df_predict_high.OUTAGE = df_predict_high.OUTAGE*1.05
    
    df_predict_low.Temp_C_0 = df_predict_low.Temp_C_0*0.95
    df_predict_high.Temp_C_0 = df_predict_high.Temp_C_0*1.05
    df_predict_low.Temp_C_1 = df_predict_low.Temp_C_1*0.95
    df_predict_high.Temp_C_1 = df_predict_high.Temp_C_1*1.05
    df_predict_low.Temp_C_2 = df_predict_low.Temp_C_2*0.95
    df_predict_high.Temp_C_2 = df_predict_high.Temp_C_2*1.05
    df_predict_low.Temp_C_3 = df_predict_low.Temp_C_3*0.95
    df_predict_high.Temp_C_3 = df_predict_high.Temp_C_3*1.05
    
    y_low = df_predict_low.pop('DAENERGY').values
    y_high = df_predict_high.pop('DAENERGY').values
    
    X_low = df_predict_low.values[:,1:]
    X_high = df_predict_high.values[:,1:]
    
    #X,y = data_lstm(X,y,lookback)
    X_low,y_low = data_mimo(X_low,y_low,lookback)
    X_high,y_high = data_mimo(X_high,y_high,lookback)
    
    input_p_low = X_low[-1:]
    input_p_high = X_high[-1:]
    
    pred_low = model.predict(input_p_low,batch_size=1)
    pred_high = model.predict(input_p_high,batch_size=1)

    results = df[date_predict].copy()
    # pred_ada = model.predict(input_p.values)
    results['forecast_low'] = pred_low[0]
    results['forecast_high'] = pred_high[0]
    
    return results

# %%
ci = get_ci('2017-09-15',model)
y_ci_u = list_scalers['DAENERGY'].inverse_transform(ci.forecast_high.values.reshape(-1,1))
y_ci_l = list_scalers['DAENERGY'].inverse_transform(ci.forecast_low.values.reshape(-1,1))

# %%
X  = np.linspace(0,24,24)
plt.plot(X,y_pred, label='forecast')
plt.plot(X,y_true, label = 'actual')
plt.plot(X,y_ci_u, '.',label = 'upper_level')
plt.plot(X,y_ci_l, '.',label = 'lower_level')

# %%
import statsmodels.api as sm

dta = sm.datasets.co2.load_pandas().data
# deal with missing values. see issue
dta.co2.interpolate(inplace=True)

res = sm.tsa.seasonal_decompose(dta.co2)
resplot = res.plot()
