# %%
from process_data import clean_data, create_index, pivot_data, clean_data2
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, LSTM, Dropout, Activation, TimeDistributed
from keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
from keras.models import load_model
import matplotlib.pyplot as plt
import time
import datetime
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

# %%
def data_recursive(X,y):
    newX = []
    newY = []
    for i in range(len(y)-lookback):
        newX.append(X[i:i+1+lookback,:])
        newY.append(y[i:i+1+lookback])
    return np.array(newX), np.array(newY)



def mlp(num_features):
    model = Sequential()
    model.add(Dense(24,activation='tanh',input_dim=num_features))
    model.add(Dropout(0.2))
    model.add(Dense(24,activation='tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(1,activation='linear'))
    model.compile(loss='mean_squared_error', optimizer='adam')
    model.summary()
    return model


def train_rnn(df,date_predict,lookback,epochs=100):
    #Preparting data to Train
    print('Preparing data to Train')
    date_p = datetime.datetime.strptime(date_predict, "%Y-%m-%d").date()
    date_limit = (date_p - datetime.timedelta(days=1)).strftime('%Y-%m-%d')
    date_start = (date_p - datetime.timedelta(days=90+lookback//24)).strftime('%Y-%m-%d')
    sk = df[:date_limit].copy()
    print(sk.shape)
    sk = sk.drop(['TRADEDATE', 'RTENERGY'], axis=1)

    #sk.hourofday = sk.hourofday.dt.seconds/3600
    #######
    sk['d1'] = sk.DAENERGY.shift(1)
    #######
    
    sk = sk[date_start:]
    #sk = sk[24:]
    print('Shape os SK:',sk.shape)
    y = sk.pop('DAENERGY').values
    X = sk.values[:,1:]
    
    print('Shape of X',X.shape)
    #X = X[1:]
    #y = y[1:]
    print('Shape of X',X.shape)
    print('YYYY')
    print(y.shape)
    
    model = mlp(X.shape[1])
    #model = create_rnn(lookback,X.shape[2])

    #X = X.reshape(X.shape[0],X.shape[1],1)
    filepath="weights-improvement-{epoch:02d}-{val_loss:.2f}.hdf5"
    filepath="best_model_mlp-recursive.hdf5"

    checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
    early_stop = EarlyStopping(monitor='val_loss', patience=30, verbose=1)
    tensorboard = TensorBoard(log_dir='./logs/mlp'+str(time.time()), 
                              histogram_freq=0, 
                              batch_size=24, 
                              write_graph=True, 
                              write_grads=False, 
                              write_images=True, 
                              )
    # #Training Model
    model.fit(
        X,
        y,
        batch_size=24,  #168, 
        epochs=epochs,
        shuffle = False,
        validation_split=0.1, callbacks=[tensorboard, checkpoint, early_stop])  #0.0857 #0.05 #0.1

    #preparing data to Predict
    return model, X, y

def predict_day(date_predict,model,lookback=168):
    date_p = datetime.datetime.strptime(date_predict, "%Y-%m-%d").date()
    date_limit = (date_p - datetime.timedelta(days=1)).strftime('%Y-%m-%d')
    date_start = (date_p - datetime.timedelta(days=42)).strftime('%Y-%m-%d')

    df_predict = df.copy()
    df_predict = df_predict[:date_predict]

    df_predict = df_predict.drop(['TRADEDATE', 'RTENERGY'], axis=1)

    #df_predict.hourofday = df_predict.hourofday.dt.seconds/3600
    
    #######
    df_predict['d1'] = df_predict.DAENERGY.shift(1)
    #######
    
    df_predict = df_predict[date_start:]
    y = df_predict.pop('DAENERGY').values
    X = df_predict.values[:,1:]
    #X,y = data_lstm(X,y,lookback)
    #X,y = data_mimo(X,y,lookback)
    input_p = X[-24:]   #-24
    #print('inpout_p.shape ',input_p.shape)
    #input_p = X[-1:]
    pred = []
    p = input_p[0,14]
    for inp in input_p:
        #print('inp', inp.shape)
        inp[14]=p
        p = model.predict(inp.reshape(1,inp.shape[0]),batch_size=1)
        pred.append(p)
        
    results = df[date_predict].copy()
    # pred_ada = model.predict(input_p.values)
    results['forecast'] = pred
    RMSE = get_rmse(results['DAENERGY'].values, pred)
    return results, RMSE

def plot_results(results,date_predict):
    RMSE = get_rmse(results['DAENERGY'], results['forecast'])
    fig, ax = plt.subplots(figsize=(9,4))
    # npre = 24
    ax.set(title='DAENERGY '+ 'RMSE: {:.3f} for {}'.format(RMSE, date_predict), xlabel='Date', ylabel='Price DAENERGY')
    #
    # # Plot data points
    results['DAENERGY'].plot(ax=ax, style='o', label='Observed')
    #
    # # Plot predictions
    results.forecast.plot(ax=ax, style='r--', label='forecast')
    # #ci = predict_ci.loc[date_predict]
    # #ax.fill_between(ci.index, ci.iloc[:,0], ci.iloc[:,1], color='r', alpha=0.1)
    legend = ax.legend(loc='lower right')


def get_rmse(pred,real):
    return np.sqrt(((pred-real)**2).sum()/pred.shape[0])

def create_date_range(start_date, end_date):
    start_dt = datetime.datetime.strptime(start_date, "%Y-%m-%d").date()
    end_dt = datetime.datetime.strptime(end_date, "%Y-%m-%d").date()
    dates = []
    cur_dt = start_dt
    dates.append(start_date)
    while cur_dt<end_dt:
        cur_dt = cur_dt + datetime.timedelta(days=1)
        dates.append(cur_dt.strftime('%Y-%m-%d'))
    return dates


def create_features(df):
    df = df.copy()
    features = ['Ph-1', 'Ph-2', 'Ph-3', 'Ph-24', 'Ph-25', 'Ph-48', 'Ph-49',
                'Ph-72','Ph-73', 'Ph-96', 'Ph-97', 'Ph-120', 'Ph-121', 'Ph-144',
                'Ph-145', 'Ph-168']
    deltas = [1, 2, 3, 24, 25, 48, 49, 72, 73, 96, 97, 120, 121, 144, 145, 168]

    for col, shift in zip(features, deltas):
        df[col] = df.DAENERGY.shift(shift)
    return df

def create_rollings(df):
    df = df.copy()
    means_cols = ['mean_3','mean_6','mean_9','mean_12','mean_24']
    means_values = [3,6,9,12,24]
    
    for col, val in zip(means_cols, means_values):
        df[col] = pd.Series.rolling(df.DAENERGY, window=val, center = False).mean()
        df[col] = df[col].shift(24)
    
    #df['p_1'] = df.DAENERGY.shift(1)
    df['p_24'] = df.DAENERGY.shift(24)
    df['p_48'] = df.DAENERGY.shift(48)
    return df        

def MAPE(y_true, y_pred):
    return 1.0/len(y_true)*(np.abs((y_true-y_pred))/y_true*100).sum()

from keras.optimizers import RMSprop, Adam, Adadelta

# %%
df = pivot_data('../data/Data.txt')
#scaler = MinMaxScaler(feature_range=(-1,1)).fit(df.DAENERGY)
#df.DAENERGY = scaler.transform(df.DAENERGY)
df = clean_data(df)
df = create_index(df)
df2 = pivot_data('../data/FurtherBack.txt','2017-05-15','2017-07-07')
df2 = clean_data2(df2)
df2 = create_index(df2)
df = pd.concat([df2,df])


df = create_rollings(df)
df = df.dropna()

wdf = pd.read_csv('../data/wstation.csv', delim_whitespace=True)
temp_cols = []
cols = df.columns.values
for col in cols:
    if len(col)==4 and col not in ['LOAD', 'p_48', 'p_72']:
        temp_cols.append(col)
        
wdf = wdf.drop_duplicates(subset = ['CALL'])

temps = pd.DataFrame(temp_cols)
temps.columns = ['CALL']
result = pd.merge(temps, wdf, how='left', on=['CALL'])
result = result[['CALL','LAT','LON']]
result = result.dropna()

from sklearn.cluster import KMeans
clusters = KMeans(n_clusters = 4).fit(result[['LAT','LON']])

result['Cluster'] = clusters.labels_

df['Temp_C_0']=df[result[result.Cluster==0]['CALL']].mean(axis=1)
df['Temp_C_1']=df[result[result.Cluster==1]['CALL']].mean(axis=1)
df['Temp_C_2']=df[result[result.Cluster==2]['CALL']].mean(axis=1)
df['Temp_C_3']=df[result[result.Cluster==3]['CALL']].mean(axis=1)

df = df.drop(temp_cols, axis=1)


list_scalers = dict()
for c in df.columns.values:
    list_scalers[c] = MinMaxScaler()
    list_scalers[c].fit(df[c].values.reshape(-1,1))
    df[c] = list_scalers[c].transform(df[c].values.reshape(-1,1))


print('Training the model...')

lookback=23#72#48#168
# Out:
# Training the model...

# %%
lookback=23

# %%
#df.DAENERGY = list_scalers['DAENERGY'].inverse_transform(df.DAENERGY.values)
start = time.time()
model, X, y = train_rnn(df,'2017-10-01',lookback=23,epochs=500)
print('Training time : {}'.format(time.time() - start))
# Out:
# Preparing data to Train
# (3335, 18)
# ('Shape os SK:', (2208, 17))
# ('Shape of X', (2208, 15))
# ('Shape of X', (2208, 15))
# YYYY
# (2208,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 24)                384
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 24)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 24)                600
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 24)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 25
# =================================================================
# Total params: 1,009
# Trainable params: 1,009
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1987 samples, validate on 221 samples
# Epoch 1/500
#   24/1987 [..............................] - ETA: 1s - loss: 0.1241Epoch 00000: val_loss improved from inf to 0.02106, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 0.0530 - val_loss: 0.0211
# Epoch 2/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0661Epoch 00001: val_loss improved from 0.02106 to 0.01479, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 0.0206 - val_loss: 0.0148
# Epoch 3/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0366Epoch 00002: val_loss improved from 0.01479 to 0.01208, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 0.0132 - val_loss: 0.0121
# Epoch 4/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0252Epoch 00003: val_loss improved from 0.01208 to 0.01203, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 0.0110 - val_loss: 0.0120
# Epoch 5/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0216Epoch 00004: val_loss improved from 0.01203 to 0.01173, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 0.0082 - val_loss: 0.0117
# Epoch 6/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0097Epoch 00005: val_loss improved from 0.01173 to 0.01016, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 0.0064 - val_loss: 0.0102
# Epoch 7/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0085Epoch 00006: val_loss improved from 0.01016 to 0.00921, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 0.0065 - val_loss: 0.0092
# Epoch 8/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0088Epoch 00007: val_loss improved from 0.00921 to 0.00831, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 0.0050 - val_loss: 0.0083
# Epoch 9/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0089Epoch 00008: val_loss improved from 0.00831 to 0.00794, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 0.0051 - val_loss: 0.0079
# Epoch 10/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0038Epoch 00009: val_loss improved from 0.00794 to 0.00713, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 0.0045 - val_loss: 0.0071
# Epoch 11/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0037Epoch 00010: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 0.0039 - val_loss: 0.0074
# Epoch 12/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0037Epoch 00011: val_loss improved from 0.00713 to 0.00698, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 0.0036 - val_loss: 0.0070
# Epoch 13/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0037Epoch 00012: val_loss improved from 0.00698 to 0.00660, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 0.0038 - val_loss: 0.0066
# Epoch 14/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0018Epoch 00013: val_loss improved from 0.00660 to 0.00655, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 0.0030 - val_loss: 0.0066
# Epoch 15/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0029Epoch 00014: val_loss improved from 0.00655 to 0.00593, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 0.0029 - val_loss: 0.0059
# Epoch 16/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0045Epoch 00015: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 0.0029 - val_loss: 0.0063
# Epoch 17/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0036Epoch 00016: val_loss improved from 0.00593 to 0.00576, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 0.0025 - val_loss: 0.0058
# Epoch 18/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0024Epoch 00017: val_loss improved from 0.00576 to 0.00576, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 0.0026 - val_loss: 0.0058
# Epoch 19/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0017Epoch 00018: val_loss improved from 0.00576 to 0.00561, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 0.0023 - val_loss: 0.0056
# Epoch 20/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0013Epoch 00019: val_loss improved from 0.00561 to 0.00504, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 0.0022 - val_loss: 0.0050
# Epoch 21/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0022Epoch 00020: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 0.0020 - val_loss: 0.0051
# Epoch 22/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0016Epoch 00021: val_loss improved from 0.00504 to 0.00497, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 0.0019 - val_loss: 0.0050
# Epoch 23/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0013Epoch 00022: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 0.0020 - val_loss: 0.0063
# Epoch 24/500
#   24/1987 [..............................] - ETA: 0s - loss: 8.4366e-04Epoch 00023: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 0.0019 - val_loss: 0.0052
# Epoch 25/500
#   24/1987 [..............................] - ETA: 0s - loss: 9.3442e-04Epoch 00024: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 0.0019 - val_loss: 0.0053
# Epoch 26/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0011Epoch 00025: val_loss improved from 0.00497 to 0.00457, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 0.0018 - val_loss: 0.0046
# Epoch 27/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0032Epoch 00026: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 0.0017 - val_loss: 0.0046
# Epoch 28/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0014Epoch 00027: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 0.0015 - val_loss: 0.0049
# Epoch 29/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0013Epoch 00028: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 0.0014 - val_loss: 0.0050
# Epoch 30/500
#   24/1987 [..............................] - ETA: 0s - loss: 7.8435e-04Epoch 00029: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 0.0016 - val_loss: 0.0050
# Epoch 31/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0016Epoch 00030: val_loss improved from 0.00457 to 0.00446, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 0.0013 - val_loss: 0.0045
# Epoch 32/500
#   24/1987 [..............................] - ETA: 0s - loss: 7.7532e-04Epoch 00031: val_loss improved from 0.00446 to 0.00445, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 0.0014 - val_loss: 0.0045
# Epoch 33/500
#   24/1987 [..............................] - ETA: 0s - loss: 9.9145e-04Epoch 00032: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 0.0014 - val_loss: 0.0046
# Epoch 34/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0017Epoch 00033: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 0.0013 - val_loss: 0.0047
# Epoch 35/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0011Epoch 00034: val_loss improved from 0.00445 to 0.00422, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 0.0013 - val_loss: 0.0042
# Epoch 36/500
#   24/1987 [..............................] - ETA: 0s - loss: 8.3831e-04Epoch 00035: val_loss improved from 0.00422 to 0.00413, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 0.0013 - val_loss: 0.0041
# Epoch 37/500
#   24/1987 [..............................] - ETA: 0s - loss: 7.7770e-04Epoch 00036: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0045
# Epoch 38/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0014Epoch 00037: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 0.0012 - val_loss: 0.0044
# Epoch 39/500
#   24/1987 [..............................] - ETA: 0s - loss: 6.7409e-04Epoch 00038: val_loss improved from 0.00413 to 0.00405, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0041
# Epoch 40/500
#   24/1987 [..............................] - ETA: 0s - loss: 7.6386e-04Epoch 00039: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0046
# Epoch 41/500
#   24/1987 [..............................] - ETA: 0s - loss: 9.1456e-04Epoch 00040: val_loss improved from 0.00405 to 0.00387, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 9.7545e-04 - val_loss: 0.0039
# Epoch 42/500
#   24/1987 [..............................] - ETA: 0s - loss: 8.7550e-04Epoch 00041: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 0.0011 - val_loss: 0.0047
# Epoch 43/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.1996e-04Epoch 00042: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 9.3356e-04 - val_loss: 0.0039
# Epoch 44/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.6169e-04Epoch 00043: val_loss improved from 0.00387 to 0.00380, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 9.5461e-04 - val_loss: 0.0038
# Epoch 45/500
#   24/1987 [..............................] - ETA: 0s - loss: 7.6510e-04Epoch 00044: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 9.2640e-04 - val_loss: 0.0039
# Epoch 46/500
#   24/1987 [..............................] - ETA: 0s - loss: 8.5692e-04Epoch 00045: val_loss improved from 0.00380 to 0.00370, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 9.6117e-04 - val_loss: 0.0037
# Epoch 47/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0012Epoch 00046: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0039
# Epoch 48/500
#   24/1987 [..............................] - ETA: 0s - loss: 5.7687e-04Epoch 00047: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 9.3797e-04 - val_loss: 0.0038
# Epoch 49/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.1065e-04Epoch 00048: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 9.4538e-04 - val_loss: 0.0039
# Epoch 50/500
#   24/1987 [..............................] - ETA: 0s - loss: 6.9028e-04Epoch 00049: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 9.1762e-04 - val_loss: 0.0040
# Epoch 51/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.4218e-04Epoch 00050: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 9.5535e-04 - val_loss: 0.0038
# Epoch 52/500
#   24/1987 [..............................] - ETA: 0s - loss: 7.6252e-04Epoch 00051: val_loss improved from 0.00370 to 0.00348, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 9.2741e-04 - val_loss: 0.0035
# Epoch 53/500
#   24/1987 [..............................] - ETA: 0s - loss: 5.5764e-04Epoch 00052: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 8.1882e-04 - val_loss: 0.0035
# Epoch 54/500
#   24/1987 [..............................] - ETA: 0s - loss: 7.7046e-04Epoch 00053: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 8.8442e-04 - val_loss: 0.0037
# Epoch 55/500
#   24/1987 [..............................] - ETA: 0s - loss: 5.8223e-04Epoch 00054: val_loss improved from 0.00348 to 0.00345, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 8.3723e-04 - val_loss: 0.0035
# Epoch 56/500
#   24/1987 [..............................] - ETA: 0s - loss: 6.3652e-04Epoch 00055: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 8.0901e-04 - val_loss: 0.0037
# Epoch 57/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.9200e-04Epoch 00056: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 8.9129e-04 - val_loss: 0.0038
# Epoch 58/500
#   24/1987 [..............................] - ETA: 0s - loss: 3.4120e-04Epoch 00057: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 8.6624e-04 - val_loss: 0.0037
# Epoch 59/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.3865e-04Epoch 00058: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 8.1418e-04 - val_loss: 0.0039
# Epoch 60/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.6237e-04Epoch 00059: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 7.3508e-04 - val_loss: 0.0035
# Epoch 61/500
#   24/1987 [..............................] - ETA: 0s - loss: 2.6957e-04Epoch 00060: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 7.4860e-04 - val_loss: 0.0035
# Epoch 62/500
#   24/1987 [..............................] - ETA: 0s - loss: 6.0390e-04Epoch 00061: val_loss improved from 0.00345 to 0.00333, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 7.5994e-04 - val_loss: 0.0033
# Epoch 63/500
#   24/1987 [..............................] - ETA: 0s - loss: 5.4738e-04Epoch 00062: val_loss improved from 0.00333 to 0.00315, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 7.8929e-04 - val_loss: 0.0032
# Epoch 64/500
#   24/1987 [..............................] - ETA: 0s - loss: 5.6876e-04Epoch 00063: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 7.5917e-04 - val_loss: 0.0035
# Epoch 65/500
#   24/1987 [..............................] - ETA: 0s - loss: 6.2485e-04Epoch 00064: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 7.9844e-04 - val_loss: 0.0034
# Epoch 66/500
#   24/1987 [..............................] - ETA: 0s - loss: 2.7290e-04Epoch 00065: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 7.7277e-04 - val_loss: 0.0033
# Epoch 67/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.6997e-04Epoch 00066: val_loss improved from 0.00315 to 0.00296, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 7.0759e-04 - val_loss: 0.0030
# Epoch 68/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.2179e-04Epoch 00067: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.9957e-04 - val_loss: 0.0033
# Epoch 69/500
#   24/1987 [..............................] - ETA: 0s - loss: 3.6222e-04Epoch 00068: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.5069e-04 - val_loss: 0.0033
# Epoch 70/500
#   24/1987 [..............................] - ETA: 0s - loss: 3.5728e-04Epoch 00069: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.5415e-04 - val_loss: 0.0031
# Epoch 71/500
#   24/1987 [..............................] - ETA: 0s - loss: 2.7777e-04Epoch 00070: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.1708e-04 - val_loss: 0.0030
# Epoch 72/500
#   24/1987 [..............................] - ETA: 0s - loss: 3.2525e-04Epoch 00071: val_loss improved from 0.00296 to 0.00295, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 6.9079e-04 - val_loss: 0.0030
# Epoch 73/500
#   24/1987 [..............................] - ETA: 0s - loss: 5.7266e-04Epoch 00072: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.5638e-04 - val_loss: 0.0030
# Epoch 74/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.1296e-04Epoch 00073: val_loss improved from 0.00295 to 0.00278, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 6.8702e-04 - val_loss: 0.0028
# Epoch 75/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0011Epoch 00074: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.3500e-04 - val_loss: 0.0030
# Epoch 76/500
#   24/1987 [..............................] - ETA: 0s - loss: 8.0053e-04Epoch 00075: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.2158e-04 - val_loss: 0.0033
# Epoch 77/500
#   24/1987 [..............................] - ETA: 0s - loss: 5.8391e-04Epoch 00076: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 7.0246e-04 - val_loss: 0.0030
# Epoch 78/500
#   24/1987 [..............................] - ETA: 0s - loss: 7.0117e-04Epoch 00077: val_loss improved from 0.00278 to 0.00278, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 7.0563e-04 - val_loss: 0.0028
# Epoch 79/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.8153e-04Epoch 00078: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.1459e-04 - val_loss: 0.0029
# Epoch 80/500
#   24/1987 [..............................] - ETA: 0s - loss: 7.8055e-04Epoch 00079: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 7.2373e-04 - val_loss: 0.0029
# Epoch 81/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.8365e-04Epoch 00080: val_loss improved from 0.00278 to 0.00277, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 6.6085e-04 - val_loss: 0.0028
# Epoch 82/500
#   24/1987 [..............................] - ETA: 0s - loss: 5.6012e-04Epoch 00081: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.0051e-04 - val_loss: 0.0029
# Epoch 83/500
#   24/1987 [..............................] - ETA: 0s - loss: 3.7885e-04Epoch 00082: val_loss improved from 0.00277 to 0.00269, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 6.3217e-04 - val_loss: 0.0027
# Epoch 84/500
#   24/1987 [..............................] - ETA: 0s - loss: 5.9429e-04Epoch 00083: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.8646e-04 - val_loss: 0.0027
# Epoch 85/500
#   24/1987 [..............................] - ETA: 0s - loss: 3.9001e-04Epoch 00084: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.9390e-04 - val_loss: 0.0028
# Epoch 86/500
#   24/1987 [..............................] - ETA: 0s - loss: 5.9160e-04Epoch 00085: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.6259e-04 - val_loss: 0.0028
# Epoch 87/500
#   24/1987 [..............................] - ETA: 0s - loss: 5.6705e-04Epoch 00086: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 7.0310e-04 - val_loss: 0.0027
# Epoch 88/500
#   24/1987 [..............................] - ETA: 0s - loss: 3.2241e-04Epoch 00087: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.3647e-04 - val_loss: 0.0029
# Epoch 89/500
#   24/1987 [..............................] - ETA: 0s - loss: 3.2055e-04Epoch 00088: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.7273e-04 - val_loss: 0.0027
# Epoch 90/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.9750e-04Epoch 00089: val_loss improved from 0.00269 to 0.00268, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 5.7338e-04 - val_loss: 0.0027
# Epoch 91/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.8663e-04Epoch 00090: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.7713e-04 - val_loss: 0.0028
# Epoch 92/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.8906e-04Epoch 00091: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.1889e-04 - val_loss: 0.0028
# Epoch 93/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.1121e-04Epoch 00092: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.6027e-04 - val_loss: 0.0028
# Epoch 94/500
#   24/1987 [..............................] - ETA: 0s - loss: 6.7795e-04Epoch 00093: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.7563e-04 - val_loss: 0.0028
# Epoch 95/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.1833e-04Epoch 00094: val_loss improved from 0.00268 to 0.00255, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 6.0477e-04 - val_loss: 0.0026
# Epoch 96/500
#   24/1987 [..............................] - ETA: 0s - loss: 3.3641e-04Epoch 00095: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.3911e-04 - val_loss: 0.0027
# Epoch 97/500
#   24/1987 [..............................] - ETA: 0s - loss: 7.1555e-04Epoch 00096: val_loss improved from 0.00255 to 0.00251, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 6.8828e-04 - val_loss: 0.0025
# Epoch 98/500
#   24/1987 [..............................] - ETA: 0s - loss: 5.8218e-04Epoch 00097: val_loss improved from 0.00251 to 0.00244, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 6.3431e-04 - val_loss: 0.0024
# Epoch 99/500
#   24/1987 [..............................] - ETA: 0s - loss: 6.7142e-04Epoch 00098: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.3321e-04 - val_loss: 0.0026
# Epoch 100/500
#   24/1987 [..............................] - ETA: 0s - loss: 3.9400e-04Epoch 00099: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.7921e-04 - val_loss: 0.0026
# Epoch 101/500
#   24/1987 [..............................] - ETA: 0s - loss: 5.0909e-04Epoch 00100: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.8100e-04 - val_loss: 0.0026
# Epoch 102/500
#   24/1987 [..............................] - ETA: 0s - loss: 7.7225e-04Epoch 00101: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.5964e-04 - val_loss: 0.0026
# Epoch 103/500
#   24/1987 [..............................] - ETA: 0s - loss: 6.1452e-04Epoch 00102: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.7536e-04 - val_loss: 0.0027
# Epoch 104/500
#   24/1987 [..............................] - ETA: 0s - loss: 3.8969e-04Epoch 00103: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.8641e-04 - val_loss: 0.0026
# Epoch 105/500
#   24/1987 [..............................] - ETA: 0s - loss: 5.6208e-04Epoch 00104: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.7647e-04 - val_loss: 0.0025
# Epoch 106/500
#   24/1987 [..............................] - ETA: 0s - loss: 5.9195e-04Epoch 00105: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.8405e-04 - val_loss: 0.0026
# Epoch 107/500
#   24/1987 [..............................] - ETA: 0s - loss: 8.1512e-04Epoch 00106: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.1522e-04 - val_loss: 0.0026
# Epoch 108/500
#   24/1987 [..............................] - ETA: 0s - loss: 8.0769e-04Epoch 00107: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.9285e-04 - val_loss: 0.0026
# Epoch 109/500
#   24/1987 [..............................] - ETA: 0s - loss: 5.1329e-04Epoch 00108: val_loss improved from 0.00244 to 0.00240, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 5.9154e-04 - val_loss: 0.0024
# Epoch 110/500
#   24/1987 [..............................] - ETA: 0s - loss: 7.8389e-04Epoch 00109: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.2188e-04 - val_loss: 0.0026
# Epoch 111/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.8990e-04Epoch 00110: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.8035e-04 - val_loss: 0.0026
# Epoch 112/500
#   24/1987 [..............................] - ETA: 0s - loss: 3.7065e-04Epoch 00111: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.1662e-04 - val_loss: 0.0026
# Epoch 113/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.0563e-04Epoch 00112: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.0151e-04 - val_loss: 0.0025
# Epoch 114/500
#   24/1987 [..............................] - ETA: 0s - loss: 7.2220e-04Epoch 00113: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.3485e-04 - val_loss: 0.0025
# Epoch 115/500
#   24/1987 [..............................] - ETA: 0s - loss: 7.0916e-04Epoch 00114: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.9817e-04 - val_loss: 0.0025
# Epoch 116/500
#   24/1987 [..............................] - ETA: 0s - loss: 6.8120e-04Epoch 00115: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.8283e-04 - val_loss: 0.0026
# Epoch 117/500
#   24/1987 [..............................] - ETA: 0s - loss: 6.2685e-04Epoch 00116: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.8949e-04 - val_loss: 0.0025
# Epoch 118/500
#   24/1987 [..............................] - ETA: 0s - loss: 9.1073e-04Epoch 00117: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.2151e-04 - val_loss: 0.0024
# Epoch 119/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.8534e-04Epoch 00118: val_loss improved from 0.00240 to 0.00231, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 6.2328e-04 - val_loss: 0.0023
# Epoch 120/500
#   24/1987 [..............................] - ETA: 0s - loss: 6.2995e-04Epoch 00119: val_loss improved from 0.00231 to 0.00230, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 6.1006e-04 - val_loss: 0.0023
# Epoch 121/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.6794e-04Epoch 00120: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.4531e-04 - val_loss: 0.0024
# Epoch 122/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.3552e-04Epoch 00121: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.9307e-04 - val_loss: 0.0024
# Epoch 123/500
#   24/1987 [..............................] - ETA: 0s - loss: 8.3189e-04Epoch 00122: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.8734e-04 - val_loss: 0.0024
# Epoch 124/500
#   24/1987 [..............................] - ETA: 0s - loss: 5.1984e-04Epoch 00123: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.4495e-04 - val_loss: 0.0025
# Epoch 125/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.4922e-04Epoch 00124: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.1849e-04 - val_loss: 0.0024
# Epoch 126/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.0655e-04Epoch 00125: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.2378e-04 - val_loss: 0.0024
# Epoch 127/500
#   24/1987 [..............................] - ETA: 0s - loss: 7.1520e-04Epoch 00126: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.7581e-04 - val_loss: 0.0025
# Epoch 128/500
#   24/1987 [..............................] - ETA: 0s - loss: 5.2511e-04Epoch 00127: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.2924e-04 - val_loss: 0.0024
# Epoch 129/500
#   24/1987 [..............................] - ETA: 0s - loss: 9.3884e-04Epoch 00128: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.8963e-04 - val_loss: 0.0024
# Epoch 130/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.8873e-04Epoch 00129: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.1079e-04 - val_loss: 0.0024
# Epoch 131/500
#   24/1987 [..............................] - ETA: 0s - loss: 6.1011e-04Epoch 00130: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.6783e-04 - val_loss: 0.0025
# Epoch 132/500
#   24/1987 [..............................] - ETA: 0s - loss: 3.2318e-04Epoch 00131: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.8710e-04 - val_loss: 0.0025
# Epoch 133/500
#   24/1987 [..............................] - ETA: 0s - loss: 2.4764e-04Epoch 00132: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.6279e-04 - val_loss: 0.0025
# Epoch 134/500
#   24/1987 [..............................] - ETA: 0s - loss: 8.5347e-04Epoch 00133: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.2353e-04 - val_loss: 0.0024
# Epoch 135/500
#   24/1987 [..............................] - ETA: 0s - loss: 8.5225e-04Epoch 00134: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.9796e-04 - val_loss: 0.0024
# Epoch 136/500
#   24/1987 [..............................] - ETA: 0s - loss: 7.8459e-04Epoch 00135: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.8770e-04 - val_loss: 0.0024
# Epoch 137/500
#   24/1987 [..............................] - ETA: 0s - loss: 8.1078e-04Epoch 00136: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.5872e-04 - val_loss: 0.0025
# Epoch 138/500
#   24/1987 [..............................] - ETA: 0s - loss: 5.2946e-04Epoch 00137: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.1337e-04 - val_loss: 0.0026
# Epoch 139/500
#   24/1987 [..............................] - ETA: 0s - loss: 9.6320e-04Epoch 00138: val_loss improved from 0.00230 to 0.00229, saving model to best_model_mlp-recursive.hdf5
# 1987/1987 [==============================] - 0s - loss: 5.0499e-04 - val_loss: 0.0023
# Epoch 140/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.2047e-04Epoch 00139: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.2813e-04 - val_loss: 0.0025
# Epoch 141/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.2138e-04Epoch 00140: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.2828e-04 - val_loss: 0.0023
# Epoch 142/500
#   24/1987 [..............................] - ETA: 0s - loss: 5.7335e-04Epoch 00141: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.8455e-04 - val_loss: 0.0024
# Epoch 143/500
#   24/1987 [..............................] - ETA: 0s - loss: 8.5284e-04Epoch 00142: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.1497e-04 - val_loss: 0.0024
# Epoch 144/500
#   24/1987 [..............................] - ETA: 0s - loss: 5.5428e-04Epoch 00143: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.6256e-04 - val_loss: 0.0026
# Epoch 145/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.6918e-04Epoch 00144: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.9933e-04 - val_loss: 0.0024
# Epoch 146/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0012Epoch 00145: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.0374e-04 - val_loss: 0.0024
# Epoch 147/500
#   24/1987 [..............................] - ETA: 0s - loss: 6.6272e-04Epoch 00146: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.6370e-04 - val_loss: 0.0024
# Epoch 148/500
#   24/1987 [..............................] - ETA: 0s - loss: 0.0011Epoch 00147: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.6616e-04 - val_loss: 0.0026
# Epoch 149/500
#   24/1987 [..............................] - ETA: 0s - loss: 6.2111e-04Epoch 00148: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.6901e-04 - val_loss: 0.0024
# Epoch 150/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.8211e-04Epoch 00149: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.7222e-04 - val_loss: 0.0024
# Epoch 151/500
#   24/1987 [..............................] - ETA: 0s - loss: 7.9774e-04Epoch 00150: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.4710e-04 - val_loss: 0.0024
# Epoch 152/500
#   24/1987 [..............................] - ETA: 0s - loss: 7.4959e-04Epoch 00151: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.1332e-04 - val_loss: 0.0024
# Epoch 153/500
#   24/1987 [..............................] - ETA: 0s - loss: 8.4333e-04Epoch 00152: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.0933e-04 - val_loss: 0.0025
# Epoch 154/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.5765e-04Epoch 00153: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.1143e-04 - val_loss: 0.0023
# Epoch 155/500
#   24/1987 [..............................] - ETA: 0s - loss: 7.4470e-04Epoch 00154: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.7955e-04 - val_loss: 0.0024
# Epoch 156/500
#   24/1987 [..............................] - ETA: 0s - loss: 7.5384e-04Epoch 00155: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.6911e-04 - val_loss: 0.0025
# Epoch 157/500
#   24/1987 [..............................] - ETA: 0s - loss: 5.7704e-04Epoch 00156: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.1336e-04 - val_loss: 0.0026
# Epoch 158/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.2010e-04Epoch 00157: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.0464e-04 - val_loss: 0.0025
# Epoch 159/500
#   24/1987 [..............................] - ETA: 0s - loss: 7.6698e-04Epoch 00158: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.4821e-04 - val_loss: 0.0025
# Epoch 160/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.2191e-04Epoch 00159: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.9838e-04 - val_loss: 0.0025
# Epoch 161/500
#   24/1987 [..............................] - ETA: 0s - loss: 5.1449e-04Epoch 00160: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.4723e-04 - val_loss: 0.0025
# Epoch 162/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.1102e-04Epoch 00161: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.8957e-04 - val_loss: 0.0025
# Epoch 163/500
#   24/1987 [..............................] - ETA: 0s - loss: 5.7787e-04Epoch 00162: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 6.2058e-04 - val_loss: 0.0024
# Epoch 164/500
#   24/1987 [..............................] - ETA: 0s - loss: 7.0812e-04Epoch 00163: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.4171e-04 - val_loss: 0.0024
# Epoch 165/500
#   24/1987 [..............................] - ETA: 0s - loss: 7.0426e-04Epoch 00164: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.2670e-04 - val_loss: 0.0025
# Epoch 166/500
#   24/1987 [..............................] - ETA: 0s - loss: 5.6571e-04Epoch 00165: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.3097e-04 - val_loss: 0.0027
# Epoch 167/500
#   24/1987 [..............................] - ETA: 0s - loss: 6.2924e-04Epoch 00166: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.1998e-04 - val_loss: 0.0024
# Epoch 168/500
#   24/1987 [..............................] - ETA: 0s - loss: 4.6301e-04Epoch 00167: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.5583e-04 - val_loss: 0.0025
# Epoch 169/500
#   24/1987 [..............................] - ETA: 0s - loss: 5.0890e-04Epoch 00168: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 5.0066e-04 - val_loss: 0.0024
# Epoch 170/500
#   24/1987 [..............................] - ETA: 0s - loss: 3.4878e-04Epoch 00169: val_loss did not improve
# 1987/1987 [==============================] - 0s - loss: 4.4642e-04 - val_loss: 0.0024
# Epoch 00169: early stopping
# Training time : 8.35300397873

# %%
model = load_model('best_model_mlp-recursive.hdf5')

# %%
# %matplotlib inline

# %%
MAPEs = []
for day in create_date_range('2017-09-01','2017-09-5'):
    #print(day)
    results, rmse = predict_day(day,model,lookback)
    plt.figure()
    #results.DAENERGY.plot()
    #results.forecast.plot()
    y_pred = list_scalers['DAENERGY'].inverse_transform(results.forecast.values.reshape(-1,1))
    y_true = list_scalers['DAENERGY'].inverse_transform(results.DAENERGY.values.reshape(-1,1))
    MAPEs.append(MAPE(y_true, y_pred))
    y_rt = list_scalers['RTENERGY'].inverse_transform(results.RTENERGY.values.reshape(-1,1))
    X  = np.linspace(0,24,24)
    plt.plot(X,y_pred, label='forecast')
    plt.plot(X,y_true, label='actual DA')
    plt.plot(X,y_rt, label='RT')
    plt.legend(loc='best')
    y_true =y_true.reshape(24)
    y_pred = y_pred.reshape(24)
    y_rt = y_rt.reshape(24)
    mask = ((y_rt > y_true) & (y_pred > y_true)) | ((y_rt < y_true) & (y_pred < y_true))
    plt.fill_between(X,y_pred.reshape(24), y_true.reshape(24), where=mask, alpha = 0.5)


plt.figure()
plt.plot(MAPEs)
plt.title('MAPE')
plt.xlabel('time')
plt.ylabel('MAPE')
print('MAPE mean:{:.2f}'.format(np.array(MAPEs).mean()))
# Out:
# MAPE mean:17.79

# %%
MAPEs=[]
for day in create_date_range('2017-10-01','2017-10-05'):
    results, rmse = predict_day(day,model,lookback)
    plt.figure()
    #results.DAENERGY.plot()
    #results.forecast.plot()
    y_pred = list_scalers['DAENERGY'].inverse_transform(results.forecast.values.reshape(-1,1))
    y_true = list_scalers['DAENERGY'].inverse_transform(results.DAENERGY.values.reshape(-1,1))
    MAPEs.append(MAPE(y_true, y_pred))
    y_rt = list_scalers['RTENERGY'].inverse_transform(results.RTENERGY.values.reshape(-1,1))
    X  = np.linspace(0,24,24)
    plt.plot(X,y_pred, label='forecast')
    plt.plot(X,y_true, label='actual DA')
    plt.plot(X,y_rt, label='RT')
    plt.legend(loc='best')
    y_true =y_true.reshape(24)
    y_pred = y_pred.reshape(24)
    y_rt = y_rt.reshape(24)
    mask = ((y_rt > y_true) & (y_pred > y_true)) | ((y_rt < y_true) & (y_pred < y_true))
    plt.fill_between(X,y_pred.reshape(24), y_true.reshape(24), where=mask, alpha = 0.5)
plt.figure()
plt.plot(MAPEs)
plt.title('MAPE')
plt.xlabel('time')
plt.ylabel('MAPE')
print('MAPE mean:{:.2f}'.format(np.array(MAPEs).mean()))
# Out:
# MAPE mean:56.84

# %%
MAPEs=[]
day ='2017-10-02'
results, rmse = predict_day(day,model,lookback)
plt.figure(figsize = (15,10))
#results.DAENERGY.plot()
#results.forecast.plot()
#results.RTENERGY.plot()
y_pred = list_scalers['DAENERGY'].inverse_transform(results.forecast.values.reshape(-1,1))
y_true = list_scalers['DAENERGY'].inverse_transform(results.DAENERGY.values.reshape(-1,1))
y_rt = list_scalers['RTENERGY'].inverse_transform(results.RTENERGY.values.reshape(-1,1))
y_true =y_true.reshape(24)
y_pred = y_pred.reshape(24)
y_rt = y_rt.reshape(24)
mask = ((y_rt > y_true) & (y_pred > y_true)) | ((y_rt < y_true) & (y_pred < y_true))



ci = get_ci(day,model)
y_ci_u = list_scalers['DAENERGY'].inverse_transform(ci.forecast_high.values.reshape(-1,1)).reshape(24)
y_ci_l = list_scalers['DAENERGY'].inverse_transform(ci.forecast_low.values.reshape(-1,1)).reshape(24)

X  = np.linspace(0,24,24)
plt.plot(X,y_pred, label='forecast')
plt.plot(X,y_true, label = 'actual')
plt.plot(X,y_rt, label = 'RT')
#plt.plot(X,y_ci_u, '.',label = 'upper_level')
#plt.plot(X,y_ci_l, '.',label = 'lower_level')
plt.xlabel('time of day')
plt.ylabel('ENERGY PRICE')
plt.legend()
plt.fill_between(X,y_pred, y_true, where=mask, alpha = 0.5)
plt.fill_between(X,y_ci_u, y_ci_l, color = 'red',alpha = 0.5)



MAPEs.append(MAPE(y_true, y_pred))

print('MAPE mean:{:.2f}'.format(np.array(MAPEs).mean()))
# Out:
# ('pred_low shape: ', (24, 1))
# MAPE mean:10.56

# %%
def get_ci(date_predict,model):
    date_p = datetime.datetime.strptime(date_predict, "%Y-%m-%d").date()
    date_limit = (date_p - datetime.timedelta(days=1)).strftime('%Y-%m-%d')
    date_start = (date_p - datetime.timedelta(days=42)).strftime('%Y-%m-%d')

    df_predict_low = df.copy()
    df_predict_low = df_predict_low[:date_predict]

    df_predict_low = df_predict_low.drop(['TRADEDATE', 'RTENERGY'], axis=1)
    df_predict_low = df_predict_low[date_start:]
    df_predict_high = df_predict_low.copy()
    
    df_predict_low.LOAD = df_predict_low.LOAD*0.95
    df_predict_high.LOAD = df_predict_high.LOAD*1.05
    
    df_predict_low.ISOWIND = df_predict_low.ISOWIND*1.05
    df_predict_high.ISOWIND = df_predict_high.ISOWIND*0.95
    
    df_predict_low.OUTAGE = df_predict_low.OUTAGE*0.95
    df_predict_high.OUTAGE = df_predict_high.OUTAGE*1.05
    
    df_predict_low.Temp_C_0 = df_predict_low.Temp_C_0*0.95
    df_predict_high.Temp_C_0 = df_predict_high.Temp_C_0*1.05
    df_predict_low.Temp_C_1 = df_predict_low.Temp_C_1*0.95
    df_predict_high.Temp_C_1 = df_predict_high.Temp_C_1*1.05
    df_predict_low.Temp_C_2 = df_predict_low.Temp_C_2*0.95
    df_predict_high.Temp_C_2 = df_predict_high.Temp_C_2*1.05
    df_predict_low.Temp_C_3 = df_predict_low.Temp_C_3*0.95
    df_predict_high.Temp_C_3 = df_predict_high.Temp_C_3*1.05
    
    y_low = df_predict_low.pop('DAENERGY').values
    y_high = df_predict_high.pop('DAENERGY').values
    
    X_low = df_predict_low.values[:,1:]
    X_high = df_predict_high.values[:,1:]
    
    #X,y = data_lstm(X,y,lookback)
    #X_low,y_low = data_mimo(X_low,y_low,lookback)
    #X_high,y_high = data_mimo(X_high,y_high,lookback)
    
    input_p_low = X_low[-24:]
    input_p_high = X_high[-24:]
    
    pred_low = model.predict(input_p_low,batch_size=24)
    pred_high = model.predict(input_p_high,batch_size=24)

    print('pred_low shape: ', pred_low.shape)
    results = df[date_predict].copy()
    # pred_ada = model.predict(input_p.values)
    results['forecast_low'] = pred_low
    results['forecast_high'] = pred_high
    
    return results

# %%
ci = get_ci('2017-10-01',model)
y_ci_u = list_scalers['DAENERGY'].inverse_transform(ci.forecast_high.values.reshape(-1,1))
y_ci_l = list_scalers['DAENERGY'].inverse_transform(ci.forecast_low.values.reshape(-1,1))

# %%
X  = np.linspace(0,24,24)
plt.plot(X,y_pred, label='forecast')
plt.plot(X,y_true, label = 'actual')
plt.plot(X,y_ci_u, '.',label = 'upper_level')
plt.plot(X,y_ci_l, '.',label = 'lower_level')
